# %% [markdown]
# ### Calss Test-2
#
# #### 1. What is String in Python?
# #### 2. Difference between find() and index()?
# #### 3. Difference between split() and join()?
# #### 4. Difference between strip(), lstrip(), rstrip()
# #### 5. What is pop() and pop(n) in list?
# #### 6. Write a python program to check whether a number is divisible by 5 or not.
# #### 7. Write a python program to check if a number is even or odd.
# #### 8. Write a python program to check whether a character is vowel or consonent.
# #### 9. Write a Python program to check if a person is child(<=12), teenager(13-19) or adult(>=20)
# #### 10. Write a Python program to classify a grade:
#     > A:90-100
#     > B:80-89
#     > C:70-79
#     > D:60:69
#     > F:Below 60
# #### 11. Write a Python program to sum of 1-10 numbers
# #### 12. Write a Python program to sum of even numbers from 1-10 and odd numbers.
