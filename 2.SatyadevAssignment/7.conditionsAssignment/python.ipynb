# %%
month = int(input(" Enter month number (1-12): "))

if month == 1:
    print("january")
elif month == 2:
    print("february")
elif month == 3:
    print("march")
elif month == 4:
    print("april")
elif month == 5:
    print("may")
elif month == 6:
    print("june")
elif month == 7:
    print("july")
elif month == 8:
    print("august")
elif month == 9:
    print("september")
elif month == 10:
    print("october")
elif month == 11:
    print("november")
elif month == 12:
    print("december")
# Out:
#  Enter month number (1-12):  7
# julu

# %%
number = int(input(" Enter number (-9 - 9): "))

if number == -9:
    print("negative")
if number == -8:
    print("negative")
if number == -7:
    print("negative")
if number == -6:
    print("negative")
if number == -5:
    print("negative")
if number == -4:
    print("negative")
if number == -3:
    print("negative")
if number == -2:
    print("negative")
if number == -1:
    print("negative")
if number == 0:
    print("zero")
if number == 1:
    print("positive")
if number == 2:
    print("positive")
if number == 3:
    print("positive")
if number == 4:
    print("positive")
if number == 5:
    print("positive")
if number == 6:
    print("positive")
if number == 7:
    print("positive")
if number == 8:
    print("positive")
if number == 9:
    print("positive")
# Out:
#  Enter number (-9 - 9):  0
# zero

# %%
number = int(input(" Enter number (0-20): "))
if number == 2:
    print("even")
if number == 4:
    print("even")
if number == 6:
    print("even")
if number == 8:
    print("even")
if number == 10:
    print("even")
if number == 12:
    print("even")
if number == 14:
    print("even")
if number == 16:
    print("even")
if number == 18:
    print("even")
if number == 20:
    print("even")
if number == 1:
    print("odd")
if number == 3:
    print("odd")
if number == 5:
    print("odd")
if number == 7:
    print("odd")
if number == 9:
    print("odd")
if number == 11:
    print("odd")
if number == 13:
    print("odd")
if number == 15:
    print("odd")
if number == 17:
    print("odd")
if number == 19: 
    print("odd")
# Out:
#  Enter number (0-20):  4
# even

# %%
age = int(input(" Enter age (0-100): "))

if age>=18:
    print("you are eligible to vote")
else:
    print("you are not eligible to vote")
# Out:
#  Enter age (0-100):  12
# you are not eligible to vote

# %%
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

if num1 > num2:
    print("The largest number is 20:", num1)
elif num2 > num1:
    print("The largest number is 40:", num2)
else:
    print("Both numbers are equal.")
# Out:
# Enter the first number:  33
# Enter the second number:  33
# Both numbers are equal.

# %%
num = int(input("Enter a number: "))

if num % 5 == 0:
    print(num, "is divisible by 5.")
else:
    print(num, "is not divisible by 5.")
# Out:
# Enter a number:  5
# 5 is divisible by 5.

# %%
num = int(input("Enter a number: "))

if num % 3 == 0 and num % 5 == 0:
    print(num, "is a multiple of both 3 and 5.")
else:
    print(num, "is not a multiple of both 3 and 5.")
# Out:
# Enter a number:  15
# 15 is a multiple of both 3 and 5.

# %%
ch = input("Enter a character: ")

if ch.lower() in ['a', 'e', 'i', 'o', 'u']:
    print(ch, "is a vowel.")
else:
    print(ch, "is a consonant.")
# Out:
# Enter a character:  k
# k is a consonant.

# %%
year = int(input("Enter a year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print(year, "is a leap year.")
else:
    print(year, "is not a leap year.")
# Out:
# Enter a year:  7
# 7 is not a leap year.

# %%
num = int(input("Enter a number: "))

if 1 <= num <= 100:
    print(num, "is within the range 1 to 100.")
else:
    print(num, "is not within the range 1 to 100.")
# Out:
# Enter a number:  90
# 90 is within the range 1 to 100.

# %%
age = int(input("Enter your age: "))

if age <= 12:
    print("The person is a Child.")
elif age >= 13 and age <= 19:
    print("The person is a Teenager.")
else:
    print("The person is an Adult.")
# Out:
# Enter your age:  87
# The person is an Adult.

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print(a, "is the largest.")
elif b >= a and b >= c:
    print(b, "is the largest.")
else:
    print(c, "is the largest.")
# Out:
# Enter first number:  8
# Enter second number:  9
# Enter third number:  7
# 9 is the largest.

# %%
num = int(input("Enter a number: "))

if num > 0:
    if num % 2 == 0:
        print("Positive and Even")
    else:
        print("Positive and Odd")
else:
    print("Negative")
# Out:
# Enter a number:  88
# Positive and Even

# %%
num = abs(int(input("Enter a number: ")))

if num <= 9:
    print("Single-digit number")
elif num <= 99:
    print("Two-digit number")
else:
    print("More than two digits")
# Out:
# Enter a number:  79
# Two-digit number

# %%
marks = int(input("Enter marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
elif marks >= 60:
    print("Grade D")
else:
    print("Grade F")
# Out:
# Enter marks:  89
# Grade B

# %%
ch = input("Enter a character: ")

if ch.isdigit():
    print("Digit")
elif ch.isupper():
    print("Uppercase Letter")
elif ch.islower():
    print("Lowercase Letter")
else:
    print("Special Character")
# Out:
# Enter a character:  '
# Special Character

# %%
year = int(input("Enter a year: "))

if year % 100 == 0:
    print("Century Year")
else:
    print("Not a Century Year")
# Out:
# Enter a year:  67
# Not a Century Year

# %%
a = int(input("Enter first side: "))
b = int(input("Enter second side: "))
c = int(input("Enter third side: "))

if a == b == c:
    print("Equilateral Triangle")
elif a == b or b == c or a == c:
    print("Isosceles Triangle")
else:
    print("Scalene Triangle")
# Out:
# Enter first side:  6
# Enter second side:  5
# Enter third side:  8
# Scalene Triangle

# %%
stored_password = "Python123"

password = input("Enter password: ")

if password == stored_password:
    print("Password Matched")
else:
    print("Incorrect Password")
# Out:
# Enter password:  77
# Incorrect Password

# %%
temp = float(input("Enter temperature in °C: "))

if temp < 20:
    print("Cold")
elif temp <= 30:
    print("Moderate")
else:
    print("Hot")
# Out:
# Enter temperature in °C:  90
# Hot

# %%
num = int(input("Enter a number: "))

if num % 2 == 0 and num % 3 == 0:
    print("Multiple of both 2 and 3")
elif num % 2 == 0:
    print("Multiple of 2 only")
elif num % 3 == 0:
    print("Multiple of 3 only")
else:
    print("Not a multiple of 2 or 3")
# Out:
# Enter a number:  0
# Multiple of both 2 and 3

# %%
amount = float(input("Enter purchase amount: "))

if amount > 1000:
    discount = amount * 0.20
elif amount >= 500:
    discount = amount * 0.10
else:
    discount = 0

print("Discount:", discount)
print("Final Amount:", amount - discount)
# Out:
# Enter purchase amount:  67
# Discount: 0
# Final Amount: 67.0

# %%
day = int(input("Enter day number (1-7): "))

if day >= 1 and day <= 5:
    print("Weekday")
elif day == 6 or day == 7:
    print("Weekend")
else:
    print("Invalid Day")
# Out:
# Enter day number (1-7):  5
# Weekday

# %%
distance = float(input("Enter distance (km): "))

if distance < 3:
    print("Walk")
elif distance <= 15:
    print("Bike")
else:
    print("Car")
# Out:
# Enter distance (km):  67
# Car

# %%
username = input("Enter username: ")

if username[0].isalpha():
    print("Username starts with a letter")
else:
    print("Username starts with a number or special character")
# Out:
# Enter username:  yt
# Username starts with a letter

# %%
units = int(input("Enter electricity units: "))

if units <= 100:
    bill = units * 1
elif units <= 200:
    bill = units * 1.5
else:
    bill = units * 2

print("Electricity Bill = ₹", bill)
# Out:
# Enter electricity units:  7
# Electricity Bill = ₹ 7

# %%
m1 = int(input("Enter marks in Subject 1: "))
m2 = int(input("Enter marks in Subject 2: "))
m3 = int(input("Enter marks in Subject 3: "))

if m1 >= 40 and m2 >= 40 and m3 >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter marks in Subject 1:  78
# Enter marks in Subject 2:  90
# Enter marks in Subject 3:  15
# Fail

# %%
year = int(input("Enter a year: "))

if year % 100 == 0 and year % 400 == 0:
    print("Leap Century Year")
else:
    print("Not a Leap Century Year")
# Out:
# Enter a year:  89
# Not a Leap Century Year

# %%
balance = float(input("Enter account balance: "))

if balance < 1000:
    print("Low Balance")
elif balance <= 5000:
    print("Medium Balance")
else:
    print("High Balance")
# Out:
# Enter account balance:  80000
# High Balance

# %%
bmi = float(input("Enter BMI: "))

if bmi < 18.5:
    print("Underweight")
elif bmi < 25:
    print("Normal")
elif bmi < 30:
    print("Overweight")
else:
    print("Obese")
# Out:
# Enter BMI:  67
# Obese

# %%
text = input("Enter a string: ")

if text == "":
    print("Empty String")
elif text.isspace():
    print("Only Spaces")
else:
    print("Contains Characters")
# Out:
# Enter a string:  -
# Contains Characters

# %% [markdown]
# ###  HOME WORK

# %%
city = input("Enter city name: ")

if city == "Delhi":
    print(["Red Fort", "Qutub Minar", "Lotus Temple"])
elif city == "Agra":
    print("Taj Mahal")
elif city == "Jaipur":
    print("Hawa Mahal, Jal Mahal")
elif city == "Amritsar":
    print("Golden Temple, Jallianwala Bagh")
elif city == "Madurai":
    print("Meenakshi Temple")
elif city == "Mysore":
    print("Mysore Palace")
elif city == "Mumbai":
    print("Gateway of India")
elif city == "Sanchi":
    print("Sanchi Stupa")
elif city == "Hyderabad":
    print("Charminar")
elif city == "Gujarat":
    print("Statue of Unity")
else:
    print("City not found")
# Out:
# Enter city name:  mumbai
# City not found

# %%
amount = float(input("Enter purchase amount: "))

if amount > 2000:
    discount = amount * 0.20
    print("Discount =", discount)
    print("Final Amount =", amount - discount)
elif amount >= 1000:
    discount = amount * 0.10
    print("Discount =", discount)
    print("Final Amount =", amount - discount)
else:
    print("No Discount")
    print("Shop ₹", 1000 - amount, "more to get minimum discount.")
# Out:
# Enter purchase amount:  8
# No Discount
# Shop ₹ 992.0 more to get minimum discount.

# %%
salary = float(input("Enter salary: "))
years = int(input("Enter years of service: "))

if years > 10:
    bonus = salary * 0.10
elif years >= 6:
    bonus = salary * 0.08
else:
    bonus = salary * 0.05

print("Bonus =", bonus)
print("Total Salary =", salary + bonus)
# Out:
# Enter salary:  78909
# Enter years of service:  3400
# Bonus = 7890.900000000001
# Total Salary = 86799.9

# %%
price = float(input("Enter bike cost: "))

if price > 100000:
    tax = price * 0.15
elif price > 50000:
    tax = price * 0.10
else:
    tax = price * 0.08

print("Road Tax =", tax)
# Out:
# Enter bike cost:  89
# Road Tax = 7.12

# %%
age = int(input("Enter age: "))

if age >= 60:
    print("Senior Citizen")
else:
    print("Not a Senior Citizen")
# Out:
# Enter age:  8
# Not a Senior Citizen

# %%
num = int(input("Enter a number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number:  -9
# Negative

# %%
working = int(input("Enter working days: "))
absent = int(input("Enter absent days: "))

present = working - absent
percentage = (present / working) * 100

print("Attendance =", percentage, "%")

if percentage >= 75:
    print("Allowed to sit in exam")
else:
    print("Not allowed to sit in exam")
# Out:
# Enter working days:  98
# Enter absent days:  90
# Attendance = 8.16326530612245 %
# Not allowed to sit in exam

# %%
marks = int(input("Enter marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
elif marks >= 60:
    print("Grade D")
elif marks >= 50:
    print("Grade E")
else:
    print("Fail")
# Out:
# Enter marks:  87
# Grade B

# %%
light = input("Enter traffic light (Green/Yellow/Red): ")

if light == "Green":
    print("Go")
elif light == "Yellow":
    print("Caution")
elif light == "Red":
    print("Stop!")
else:
    print("Invalid Input")
# Out:
# Enter traffic light (Green/Yellow/Red):  Yellow
# Caution

# %%
role = input("Enter role: ")

if role == "admin":
    print("Access granted")
elif role == "Editor":
    print("Can edit")
elif role == "viewer":
    print("Can view")
else:
    print("Unknown role")
# Out:
# Enter role:  admin
# Access granted

# %%
amount = float(input("Enter purchase amount in dollars: "))

rupees = amount * 86.99
print("Amount in Rupees = ₹", rupees)

if amount > 100:
    discount = rupees * 0.15
elif amount > 50:
    discount = rupees * 0.05
else:
    discount = 0

print("Discount = ₹", discount)
print("Final Amount = ₹", rupees - discount)
# Out:
# Enter purchase amount in dollars:  7000000
# Amount in Rupees = ₹ 608930000.0
# Discount = ₹ 91339500.0
# Final Amount = ₹ 517590500.0

# %%
ch = input("Enter a character: ")

if ch.isupper():
    print("Uppercase Letter")
elif ch.islower():
    print("Lowercase Letter")
elif ch.isdigit():
    print("Digit")
else:
    print("Special Character")
# Out:
# Enter a character:  i
# Lowercase Letter

# %%
sides = int(input("Enter number of sides: "))

if sides == 3:
    print("Triangle")
elif sides == 4:
    print("Quadrilateral")
elif sides == 5:
    print("Pentagon")
elif sides == 6:
    print("Hexagon")
elif sides == 7:
    print("Septagon")
elif sides == 8:
    print("Octagon")
else:
    print("Shape not available")
# Out:
# Enter number of sides:  4
# Quadrilateral

# %%
ch = input("Enter a character: ")

if ch.lower() in ['a', 'e', 'i', 'o', 'u']:
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a character:  e
# Vowel

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
op = input("Enter operator (+, -, *, /, ^): ")

if op == "+":
    print("Answer =", num1 + num2)
elif op == "-":
    print("Answer =", num1 - num2)
elif op == "*":
    print("Answer =", num1 * num2)
elif op == "/":
    if num2 != 0:
        print("Answer =", num1 / num2)
    else:
        print("Division by zero is not possible")
elif op == "^":
    print("Answer =", num1 ** num2)
else:
    print("Invalid Operator")
# Out:
# Enter first number:  8
# Enter second number:  9
# Enter operator (+, -, *, /, ^):  +
# Answer = 17.0
