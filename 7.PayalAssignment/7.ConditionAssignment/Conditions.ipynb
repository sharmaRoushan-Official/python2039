# %%
num = float(input("Enter a Number :"))
if num > 0:
    print("Positive Number")
elif num < 0:
    print("Negative Number")
else :
    print("Zero")
# Out:
# Enter a Number : 5
# Positive Number

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter a number:  4
# Even

# %%
age = int(input("Enter age: "))
if age >= 18:
    print("Eligible to vote")
else:
    print("Not eligible to vote")
# Out:
# Enter age:  21
# Eligible to vote

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
if a > b:
    print("Largest =", a)
else:
    print("Largest =", b)
# Out:
# Enter first number:  15
# Enter second number:  23
# Largest = 23

# %%
num = int(input("Enter a number: "))
if num % 5 == 0:
    print("Divisible by 5")
else:
    print("Not divisible by 5")
# Out:
# Enter a number:  25
# Divisible by 5

# %%
num = int(input("Enter a number: "))
if num % 3 == 0 and num % 5 == 0:
    print("Multiple of both 3 and 5")
else:
    print("Not a multiple of both")
# Out:
# Enter a number:  15
# Multiple of both 3 and 5

# %%
ch = input("Enter a character(a-z): ")
if ch in "aeiou":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter a character(a-z):  g
# Consonant

# %%
year = int(input("Enter year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")
else:
    print("Not a Leap Year")
# Out:
# Enter year:  2013
# Not a Leap Year

# %%
num = int(input("Enter a number: "))
if 1 <= num <= 100:
    print("Within range")
else:
    print("Out of range")
# Out:
# Enter a number:  55
# Within range

# %%
age = int(input("Enter age: "))
if age <= 12:
    print("Child")
elif age <= 19:
    print("Teenager")
else:
    print("Adult")
# Out:
# Enter age:  18
# Teenager

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))
if a >= b and a >= c:
    print("Largest =", a)
elif b >= a and b >= c:
    print("Largest =", b)
else:
    print("Largest =", c)
# Out:
# Enter first number:  15
# Enter second number:  34
# Enter third number:  23
# Largest = 34

# %%
num = int(input("Enter a number: "))
if num > 0:
    if num % 2 == 0:
        print("Positive Even")
    else:
        print("Positive Odd")
else:
    print("Negative")
# Out:
# Enter a number:  4
# Positive Even

# %%
num = (int(input("Enter a number: ")))
if num < 10:
    print("Single-digit")
elif num < 100:
    print("Two-digit")
else:
    print("More than two digits")
# Out:
# Enter a number:  35
# Two-digit

# %%
marks = int(input("Enter marks: "))
if marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
elif marks >= 60:
    print("Grade D")
else:
    print("Grade F")
# Out:
# Enter marks:  83
# Grade B

# %%
ch = input("Enter a character: ")
if ch.isdigit():
    print("Digit")
elif ch.isupper():
    print("Uppercase Letter")
elif ch.islower():
    print("Lowercase Letter")
else:
    print("Special Character")
# Out:
# Enter a character:  A
# Uppercase Letter

# %%
year = int(input("Enter year: "))
if year % 100 == 0:
    print("Century Year")
else:
    print("Not a Century Year")
# Out:
# Enter year:  2020
# Not a Century Year

# %%
a = int(input("Side 1: "))
b = int(input("Side 2: "))
c = int(input("Side 3: "))
if a == b == c:
    print("Equilateral")
elif a == b or b == c or a == c:
    print("Isosceles")
else:
    print("Scalene")
# Out:
# Side 1:  5
# Side 2:  5
# Side 3:  6
# Isosceles

# %%
stored_password = "python123"
password = input("Enter password: ")
if password == stored_password:
    print("Access Granted")
else:
    print("Wrong Password")
# Out:
# Enter password:  python123
# Access Granted

# %%
temp = float(input("Enter temperature: "))
if temp < 20:
    print("Cold")
elif temp <= 30:
    print("Moderate")
else:
    print("Hot")
# Out:
# Enter temperature:  25
# Moderate

# %%
num = int(input("Enter a number: "))
if num % 2 == 0 and num % 3 == 0:
    print("Multiple of both")
elif num % 2 == 0:
    print("Multiple of 2")
elif num % 3 == 0:
    print("Multiple of 3")
else:
    print("None")
# Out:
# Enter a number:  18
# Multiple of both

# %%
amount = float(input("Enter purchase amount: "))
if amount > 1000:
    discount = amount * 0.20
elif amount >= 500:
    discount = amount * 0.10
else:
    discount = 0
print("Discount =", discount)
print("Final Amount =", amount - discount)
# Out:
# Enter purchase amount:  5000
# Discount = 1000.0
# Final Amount = 4000.0

# %%
day = int(input("Enter day number (1-7): "))
if day == 6 or day == 7:
    print("Weekend")
elif 1 <= day <= 5:
    print("Weekday")
else:
    print("Invalid day")
# Out:
# Enter day number (1-7):  6
# Weekend

# %%
distance = float(input("Enter distance (km): "))
if distance < 3:
    print("Walk")
elif distance <= 15:
    print("Bike")
else:
    print("Car")
# Out:
# Enter distance (km):  20
# Car

# %%
username = input("Enter username: ")
if username[0].isalpha():
    print("Valid Username")
else:
    print("Invalid Username")
# Out:
# Enter username:  Python123
# Valid Username

# %%
units = int(input("Enter units: "))
if units <= 100:
    bill = units * 1
elif units <= 200:
    bill = units * 1.5
else:
    bill = units * 2
print("Electricity Bill = ₹", bill)
# Out:
# Enter units:  550
# Electricity Bill = ₹ 1100

# %%
m1 = int(input("Subject 1: "))
m2 = int(input("Subject 2: "))
m3 = int(input("Subject 3: "))
if m1 >= 40 and m2 >= 40 and m3 >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Subject 1:  67
# Subject 2:  87
# Subject 3:  78
# Pass

# %%
year = int(input("Enter year: "))
if year % 100 == 0 and year % 400 == 0:
    print("Leap Century Year")
else:
    print("Not a Leap Century Year")
# Out:
# Enter year:  2023
# Not a Leap Century Year

# %%
balance = float(input("Enter balance: "))
if balance < 1000:
    print("Low Balance")
elif balance <= 5000:
    print("Medium Balance")
else:
    print("High Balance")
# Out:
# Enter balance:  5000
# Medium Balance

# %%
weight = float(input("Enter weight (kg): "))
height = float(input("Enter height (m): "))
bmi = weight / (height ** 2)
print("BMI =", round(bmi, 2))

if bmi < 18.5:
    print("Underweight")
elif bmi < 25:
    print("Normal")
elif bmi < 30:
    print("Overweight")
else:
    print("Obese")
# Out:
# Enter weight (kg):  38.7
# Enter height (m):  5.5
# BMI = 1.28
# Underweight

# %%
text = input("Enter a string: ")
if text == "":
    print("Empty String")
elif text.isspace():
    print("Only Spaces")
else:
    print("Contains Characters")
# Out:
# Enter a string:
# Empty String

# %%
#Homework
city = input("Enter city name: ")
if city == "delhi":
    print(["Red Fort", "Qutub Minar", "Lotus Temple"])
elif city == "agra":
    print("Taj Mahal")
elif city == "jaipur":
    print("Hawa Mahal, Jal Mahal")
elif city == "amritsar":
    print("Golden Temple, Jallianwala Bagh")
elif city == "madurai":
    print("Meenakshi Temple")
elif city == "mysore":
    print("Mysore Palace")
elif city == "mumbai":
    print("Gateway of India")
elif city == "sanchi":
    print("Sanchi Stupa")
elif city == "hyderabad":
    print("Charminar")
elif city == "gujarat":
    print("Statue of Unity")
else:
    print("City not found")
# Out:
# Enter city name:  mumbai
# Gateway of India

# %%
amount = float(input("Enter purchase amount: ₹"))
if amount > 2000:
    discount = amount * 0.20
    print("20% Discount =", discount)
    print("Final Amount =", amount - discount)
elif amount >= 1000:
    discount = amount * 0.10
    print("10% Discount =", discount)
    print("Final Amount =", amount - discount)
else:
    print("No Discount")
    print("Shop ₹", 1000 - amount, "more to get minimum discount.")
# Out:
# Enter purchase amount: ₹ 5000
# 20% Discount = 1000.0
# Final Amount = 4000.0

# %%
salary = float(input("Enter salary: "))
years = int(input("Enter years of service: "))
if years > 10:
    bonus = salary * 0.10
elif years >= 6:
    bonus = salary * 0.08
else:
    bonus = salary * 0.05
print("Bonus =", bonus)
print("Total Salary =", salary + bonus)
# Out:
# Enter salary:  20000
# Enter years of service:  2
# Bonus = 1000.0
# Total Salary = 21000.0

# %%
price = float(input("Enter bike cost price: ₹"))
if price > 100000:
    tax = price * 0.15
elif price > 50000:
    tax = price * 0.10
else:
    tax = price * 0.08
print("Road Tax = ₹", tax)
# Out:
# Enter bike cost price: ₹ 150000
# Road Tax = ₹ 22500.0

# %%
age = int(input("Enter age: "))
if age >= 60:
    print("Senior Citizen")
else:
    print("Not a Senior Citizen")
# Out:
# Enter age:  71
# Senior Citizen

# %%
num = int(input("Enter a number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter a number:  5
# Positive

# %%
working_days = int(input("Enter total working days: "))
absent = int(input("Enter total absent days: "))
present = working_days - absent
percentage = (present / working_days) * 100
print("Attendance Percentage =", percentage)
if percentage >= 75:
    print("Allowed to sit in exam")
else:
    print("Not allowed to sit in exam")
# Out:
# Enter total working days:  330
# Enter total absent days:  32
# Attendance Percentage = 90.30303030303031
# Allowed to sit in exam

# %%
marks = int(input("Enter marks: "))
if marks >= 90:
    print("Grade A")
elif marks >= 80:
    print("Grade B")
elif marks >= 70:
    print("Grade C")
elif marks >= 60:
    print("Grade D")
elif marks >= 50:
    print("Grade E")
else:
    print("Fail")
# Out:
# Enter marks:  85
# Grade B

# %%
light = input("Enter traffic light (Green/Yellow/Red): ").lower()
if light == "green":
    print("Go")
elif light == "yellow":
    print("Caution")
elif light == "red":
    print("Stop!")
else:
    print("Invalid Traffic Light")
# Out:
# Enter traffic light (Green/Yellow/Red):  Yellow
# Caution

# %%
role = input("Enter role: ").lower()
if role == "admin":
    print("Access Granted")
elif role == "editor":
    print("Can Edit")
elif role == "viewer":
    print("View Only")
else:
    print("Unknown Role")
# Out:
# Enter role:  admin
# Access Granted

# %%
dollar = float(input("Enter purchase amount in dollars: "))
rupees = dollar * 86.99
print("Amount in Rupees = ₹", rupees)
if dollar > 100:
    discount = rupees * 0.15
elif dollar > 50:
    discount = rupees * 0.05
else:
    discount = 0
print("Discount = ₹", discount)
print("Final Amount = ₹", rupees - discount)
# Out:
# Enter purchase amount in dollars:  550
# Amount in Rupees = ₹ 47844.5
# Discount = ₹ 7176.675
# Final Amount = ₹ 40667.825

# %%
ch = input("Enter a character: ")
if ch.isupper():
    print("Uppercase Letter")
elif ch.islower():
    print("Lowercase Letter")
elif ch.isdigit():
    print("Digit")
else:
    print("Special Character")
# Out:
# Enter a character:  A
# Uppercase Letter

# %%
sides = int(input("Enter number of sides: "))
if sides == 3:
    print("Triangle")
elif sides == 4:
    print("Quadrilateral")
elif sides == 5:
    print("Pentagon")
elif sides == 6:
    print("Hexagon")
elif sides == 7:
    print("Septagon")
elif sides == 8:
    print("Octagon")
else:
    print("Shape not available")
# Out:
# Enter number of sides:  5
# Pentagon
