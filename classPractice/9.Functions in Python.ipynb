# %% [markdown]
# ### 29.Find the GCD of two numbers using loop.

# %%
num1= int(input("Enter a number 1 : "))
num2 = int(input("Enter a number 2 : "))
i=1
while i<=num1:
    if num1%i==0 and num2%i==0:
        gcd = i
    i=i+1
print(f"GCD of {num1} and {num2} is {gcd}")
# Out:
# Enter a number 1 :  3
# Enter a number 2 :  9
# GCD of 3 and 9 is 3

# %%
num1= int(input("Enter a number 1 : "))
num2 = int(input("Enter a number 2 : "))

max_num = max(num1,num2)  # choose number of maximum
# print(max_num)

while True:
    if max_num%num1 ==0 and max_num%num2==0:
        print("LCM:",max_num)
        break
    max_num+=1
# Out:
# Enter a number 1 :  12
# Enter a number 2 :  18
# LCM: 36

# %%
# LCM = (Number1*Number2)/GCD

num1= int(input("Enter a number 1 : "))
num2 = int(input("Enter a number 2 : "))

a = num1
b = num2

while b!=0:
    a,b = b, a%b
gcd = a
# print(gcd)
lcm = (num1*num2)//gcd
print("LCM:",lcm,"\nGCD:",gcd)
# Out:
# Enter a number 1 :  12
# Enter a number 2 :  36
# LCM: 36
# GCD 12

# %% [markdown]
# ### 12. Write a function area_circle(r) that returns area of circle

# %%
import math

math.pi
# Out:
# 3.141592653589793

# %%
def area_circle(r):
    area_circle = math.pi*r*r
    return f"Area of Circle is:{area_circle} cm²"
area_circle(10)
# Out:
# 'Area of Circle is:314.1592653589793 cm²'

# %%
area_circle(14)
# Out:
# 'Area of Circle is:615.7521601035994 cm²'

# %%
area_circle(12)
# Out:
# 'Area of Circle is:452.3893421169302 cm²'

# %% [markdown]
# ## 16. write a function remove_duplicates(lst) that removes duplicates from a list.

# %%
lst1 = [10,12,13,10,14,12,15,13,16]  # [10,12,13,14,15,16]

uniqueNum = []
def uniqueNumber(lst):
    for i in lst:
        if i not in uniqueNum:
            uniqueNum.append(i)
    print("Unique Number is:",uniqueNum)
uniqueNumber(lst1)
# Out:
# Unique Number is: [10, 12, 13, 14, 15, 16]

# %%
lst1 = [10,12,13,10,14,12,15,13,16]
uniqueNumber(lst1)
# Out:
# Unique Number is: [10, 12, 13, 14, 15, 16]

# %% [markdown]
# ### 22. Write a function count_occurrences(lst,item) that counts occurrences of an items.

# %%
mylist = [10,20,30,20,40,20,50]  # static list


def count_occurrence(lst,item):
    count = 0
    for i in lst:
        # print(i)
        if i == item:
           count+=1
    print(count)
item = 20
count_occurrence(mylist,item)
# Out:
# 3

# %%
# mylist = [10,20,30,20,40,20,50]


def count_occurrence(item):
    count = 0
    lst = []  # dynamic list
    for x in iter(int, 1):
        userNum = int(input("Start Enter number: "))
        if userNum == 0:
            break
        lst.append(userNum)
        
    for i in lst:
        # print(i)
        if i == item:
           count+=1
    print("Generated List of Numbers:",lst)
    print("Item Count in the list is:",count)
item = int(input("Enter Items: "))
count_occurrence(item)
# Out:
# Enter Items:  14
# Start Enter number:  15
# Start Enter number:  14
# Start Enter number:  12
# Start Enter number:  13
# Start Enter number:  14
# Start Enter number:  15
# Start Enter number:  16
# Start Enter number:  12
# Start Enter number:  36
# Start Enter number:  14
# Start Enter number:  17
# Start Enter number:  0
# Generated List of Numbers: [15, 14, 12, 13, 14, 15, 16, 12, 36, 14, 17]
# Item Count in the list is: 3

# %% [markdown]
# #### 27. Write a funciton replace_spaces(sentence) that replaces spaces with underscore(`_`)

# %%
sentence = "The Quick Brown Fox Jump Over The Lazy Dog"


def replace_spaces(sentence1):
    for sen in sentence1:
        # print(sen)
        sen = sen.replace(' ',"_")
        print(sen,end="")

replace_spaces(sentence)
# Out:
# The_Quick_Brown_Fox_Jump_Over_The_Lazy_Dog

# %%
name = "Swadhin Shau"
replace_spaces(name)
# Out:
# Swadhin_Shau

# %% [markdown]
# ### 26. Write function capitalize_words(sentence) that capitalizes first letters of each word.

# %%
sentence = "the quick brown fox jump over the lazy dog"

words = sentence.split()
capitalizeWord = ""


for word in words:
    capWord = word.capitalize()
    # print(capWord,end=" ")
    
    capitalizeWord=capitalizeWord+capWord+" "
print(capitalizeWord)
# Out:
# The Quick Brown Fox Jump Over The Lazy Dog

# %%
# start = 1
# end = 9

# for num in range(start,end+1):  # 1, 10
#     digits = len(str(num))  # 1,1,1,1,1,1,1,1,1
#     total = sum(int(digit)**digits for digit in str(num)) # 1
#     # print(total)
#     if total == num:
#         print(num)

# %%
num = 153

digits = len(str(num))  # "123"
# print(digits)

temp = num  # 12

sum1 = 0

while temp>0:  # True
    digit = temp % 10
    sum1 += digit ** digits
    temp //=10
if sum1 == num:
    print(num,"is an Armstrong Number")
else:
    print(num,"is not Armstrong Number")
# Out:
# 153 is an Armstrong Number

# %%
123%10
# Out:
# 3

# %%
3**3
# Out:
# 27

# %%
123//10
# Out:
# 12

# %%
12%10
# Out:
# 2

# %%
2**3
# Out:
# 8

# %%
27+8
# Out:
# 35

# %%
12//10
# Out:
# 1

# %%
1%10
# Out:
# 1

# %%
1**3
# Out:
# 1

# %%
27+8+1
# Out:
# 36

# %%
1//10
# Out:
# 0

# %% [markdown]
# # 34. write a function binary_to_decimal(binary)

# %%
binary = "101"

# (10101101)₂ = (1 × 2⁷) + (0 × 2⁶) + (1 × 2⁵) + (0 × 2⁴) + (1 × 2³) + (1 × 2²) + (0 × 2¹) + (1 × 2⁰)

decimal = 0
power = 0

for digit in binary[::-1]:
    decimal += int(digit)* (2**power)
    power+=1
print(decimal)
# Out:
# 5

# %%
# 64+16+8+4+1
