# %%
# print days of week based on number

month=int(input("enter number"))
if month==1:
    print("january")
elif month==2:
    print("february")
elif month==3:
    print("march")
elif month==4:
    print("april")
elif month==5:
    print("may")
elif month==6:
    print("june")
elif month==7:
    print("july")
elif month==8:
    print("august")
elif month==9:
    print("september")
elif month==10:
    print("october")
elif month==11:
    print("november")
elif month==12:
    print("december")
else:
    print ("range exceed")
# Out:
# enter number 1
# january

# %% [markdown]
# ###  1. Write a Python program to check whether a number is *positive, **negative, or **zero*.

# %%
num = float(input("Enter a number: "))

if num > 0:
    print("The number is Positive")
elif num < 0:
    print("The number is Negative")
else:
    print("The number is Zero")
# Out:
# Enter a number:  0
# The number is Zero

# %%
#print .check the odd even number by  user input

num = int(input("Enter a number: "))

if num % 2 == 0:
    print("The number is Even")
else:
    print("The number is Odd")
# Out:
# Enter a number:  6
# The number is Even

# %%
print #.check the age which is eligible for vote cond age >= 18

age = int(input("Enter your age: "))

if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote.")
# Out:
# Enter your age:  15
# You are not eligible to vote.

# %%
# print identify the largest on between two number .

num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))

if num1 > num2:
    print("The largest number is:", num1)
elif num2 > num1:
    print("The largest number is:", num2)
else:
    print("Both numbers are equal.")
# Out:
# Enter the first number:  15
# Enter the second number:  18
# The largest number is: 18.0

# %%
# print check the number which is divisible by 5.

num = int(input("Enter a number: "))

if num % 5 == 0:
    print("The number is divisible by 5.")
else:
    print("The number is not divisible by 5.")
# Out:
# Enter a number:  35
# The number is divisible by 5.

# %%
# Program to check if a number is a multiple of both 3 and 5

num = int(input("Enter a number: "))

if num % 3 == 0 and num % 5 == 0:

    print("The number is a multiple of both 3 and 5.")
else:
    print("The number is not a multiple of both 3 and 5.")
# Out:
# Enter a number:  50
# The number is not a multiple of both 3 and 5.

# %%
# Program to check whether a character is a vowel or consonant


ch = input("Enter a character: ")

if ch.lower() in ('a', 'e', 'i', 'o', 'u'):
    print("The character is a Vowel.")
elif ch.lower() in ('b','c','d','f','g','h','j',...'z'):
      print("The character is a Consonant.")
else:
    print("invalid input")
# Out:
# Enter a character:  1
# invalid input

# %%
# 9. Write a Python program to check if a number is *within the range 1–100*

num=int(input("enter your number"))

if num>0 and num<=100:
    print("number is between the range")
    
else:
    print("out of range")
# Out:
# enter your number 555
# out of range

# %%
# Write a Python program to check if a person is a *child (≤12), **teenager (13–19), or **adult (≥20)*.
age=int(input("enter the age"))
if age<=12:
    print("you are child")
elif age>13 and age<=19:
    print("you are teenager")
elif age>=20:
    print("you are adult")

else:
    print("inavaild")
# Out:
# enter the age 4
# you are child

# %%
# 11. Write a Python program to find the *largest among three numbers*.
num1=int(input("enter the number 1"))

num2=int(input("enter the number 2"))

num3=int(input("enter the number 3"))

if num1>num2 and num1>num3:
    print(f"{num1} is greaterthan {num2} and {num3}")
elif num2>num1 and num2>num3:
    print(f"{num2} is greaterthan {num1} and {num3}")
elif num3>num1 and num2:
    print(f"{num3} is greaterthan {num1} and {num2}")

else:
    print("ivaild")
# Out:
# enter the number 1 10
# enter the number 2 50
# enter the number 3 30
# 50 is greaterthan 10 and 30

# %%
#12. Write a Python program to check whether a number is *positive and even, **positive and odd, or **negative*.
num=int(input('enter the number'))
if num>0:
    if num%2==0:
        print("it is positive and even")
    else:
        print("it is poitive and odd")
else:
    print("it is a negative number")
# Out:
# enter the number 90
# it is positive and even

# %%
# 13. Write a Python program to check if a number is *a single-digit, two-digit, or more than two digits*.
num=(input("enter the number"))
length=len(num)
if length==1:
    ivaildpriivaildnt("single digit")
elif length==2:
    print("double digit")
elif length>=3:
    print("morethan three digit")
else:
    print("ivaild")
# Out:
# enter the number 57488
# morethan three digit

# %%
# 14. Write a Python program to classify a grade:

# A: 90–100
#B: 80–89
#C: 70–79
#D: 60–69
#F: Below 60

mark = int(input("enter your mark"))
if mark>=0 and mark<=100:

    if mark>=90 and mark<=100:
        print("grade A")
    elif mark>=80 and mark<=89:
        print("grade B")
    elif  mark>=70 and mark<=79:
        print("grade C")
    elif  mark>=60 and mark<=69:
        print("grade D")
    else:
        print("fail")
else:
    print("not in range")
# Out:
# enter your mark 66
# grade D

# %%
# 15. Write a Python program to check whether a character is a *digit, **uppercase letter, **lowercase letter, or **special character*.

#import string

#help(string)

# %%
ascii_lowercase = 'abcdefghijklmnopqrstuvwxyz'
ascii_uppercase = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
digits = '0123456789'
punctuation = '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

ch=input("enter the character")
if ch in ascii_lowercase:
    print("ch in lower case")
elif ch in ascii_uppercase:
    print("ch in upper case")
elif ch in digits:
    print("ch in digit")
elif ch in punctuation:
    print("ch is special character")
else:
    print("invaild input")
# Out:
# enter the character g
# ch in lower case

# %%
# 1. Accepts any city and display their Monuments.

#cityName-------------------> Monument

# "Delhi"--------------------> ['Redfort','QutubMinar','LotusTemple']
# Agra-----------------------> "TajMahal"
# Jaipur---------------------> "HawaMahal/JalMahal"
# Amritsar-------------------> "GoldenTemple,Jalliawalabagh"
# Madurai--------------------> "Meenakshi Temple"
# Mysore---------------------> "Mysore palace"
# Mumbai --------------------> "Gateway of India"
# Sanchi---------------------> "Sanchi Stupa"
# Hydrabad-------------------> "Charminar"
# Gujarat -------------------> "Statue of Unity"

listCity = ["Delhi","agra","Jaipur","Amritsar","Madurai","Mysore","Mumbai","Sanchi","Hydrabad","Gujarat"]
print("City List",listCity)
Cityname1= input("choose city: ")

cityName = Cityname1.capitalize()
if cityName=="Delhi":
    print("Monument is : ",['Redfort','QutubMinar','LotusTemple'])
elif cityName=="Agra":
    print("Monument is : ","Tajmahal")
elif cityName=="Jaipur":
    print("Monument is : ", "HawaMahal/JalMahal")
elif cityName=="Amritsar":
    print("Monument is : ","GoldenTemple,Jalliawalabagh")
elif cityName=="Madurai":
    print("Monument is : ", "Meenakshi Temple")
elif cityName=="Mysore":
    print("Monument is : ","Mysore palace")
elif cityName=="Mumbai":
    print("Monument is : ","Gateway of India")
elif cityName=="Sanchi":
    print("Monument is : ","Sanchi Stupa")
elif cityName=="Hyderabad":
    print("Monument is : ","Charminar")
elif cityName=="Gujrat":
    print("Monument is : ","Statue of Unity")
else:
    print("out of list")
# Out:
# City List ['Delhi', 'agra', 'Jaipur', 'Amritsar', 'Madurai', 'Mysore', 'Mumbai', 'Sanchi', 'Hydrabad', 'Gujarat']
# choose city:  mumbai
# Monument is :  Gateway of India

# %%
# 9. Simulate a traffic light, if the light is "Green", print "Go", If yellow, print "Caution",
# if red "Stop!"


light1 = input("Enter Light Status : ")
light=light1.capitalize()

if light=="Green":
    print("You can go")
elif light=="Yellow":
    print("Caution")
elif light == "Red":
    print("Stop")
else:
    print("invalid input")
# Out:
# Enter Light Status :  yellow
# Caution

# %%
# 17. Write a Python program to check whether a triangle is *equilateral, **isosceles, or **scalene*.
angle1=float(input("enter the angle 1"))

angle2=float(input("enter the anglr 2"))

angle3=float(input("enter the anglr 3"))

sum = angle1+angle2+angle3

if sum==180:
    if angle1==angle2 and angle2==angle3:
        print("this is equilateral ")
    elif angle1==angle2 or angle1==angle3 or angle2==angle3:
        print("this is isosceles")
    else:
        print("this is scalene ")
else:
    print("invalid")
# Out:
# enter the angle 1 60
# enter the anglr 2 50
# enter the anglr 3 70
# this is scalene

# %%
# 18. Write a Python program to check whether the entered password matches the *stored password* or not.

storePassword=str(input("enter the password to set"))

currentPassword=str(input("enter the new password "))
if storePassword==currentPassword:
    print("password matched")
else:
    print("password mismatched")
# Out:
# enter the password to set ankesh123
# enter the new password  swadhin123
# password mismatched

# %%
# 19. Write a Python program to find whether a given temperature (°C) is *cold (<20), **moderate (20–30), or **hot (>30)*.
temp=float(input("enter temperature"))

if   temp<=20:
    print:("cold")
elif temp>20 and temp<=30:
    print:("moderate")
else:
    print("hot")
# Out:
# enter temperature 76
# hot

# %%
# 20. Write a Python program to check if the entered number is *a multiple of 2, 3, both, or none*.

num=int(input("enter the number"))

if num % 2==0:
    if num % 3==0:
        print("multiple of both")
    else: 
        print("only multiple of 2")
        
elif num % 3==0:
    if num % 2==0:
        print("multiple of both")
    else:
        print("only multiple of 3")
        
else:
    print("multiple of none")
# Out:
# enter the number 5
# multiple of none

# %%
#  21. Write a Python program to calculate *discount* based on purchase amount:

    # > 1000 → 20% discount
    # 500–1000 → 10% discount
    # <500 → No discount
amount = float(input("enter the amount:  "))
if amount>1000:
     dis="20%"
     disAmount= (amount*20)/100
     totalAmount= amount - disAmount
     print(f"discount amount is {disAmount}")
     print(f"purchase amount is {totalAmount}")
elif amount>=500 and amount<=1000:
    dis="10%"
    disAmount= (amount*10)/100
    totalAmount= amount - disAmount
    print(f"discount amount is {disAmount}")
    print(f"purchase amount is {totalAmount}")
elif amount>=0 and amount<500:
 
    print("no discount")
    print(f"purchase amount{amount}")
else:
    print("ivaild amount")
# Out:
# enter the amount:   -58
# ivaild amount

# %%
# Write a Python program to check if a given *day number (1–7)* corresponds to *weekday or weekend*.
day_num = int(input("Enter day number : "))
weekend = {7:'saturday',1:'sunday'}
weekdays = {2:"monday",3:"thuesday",4:"wednesday",5:"thrusday",6:"friday"}

if day_num>0 and day_num<=7:
    if day_num in weekend:
        print("Weekend")
    else:
        print("weekday")
else:
    print("invaild")
# Out:
# Enter day number :  7
# Weekend

# %%
# 23 Write a Python program to decide the *mode of transport* based on distance:

    # <3 km: Walk
    # 3–15 km: Bike
    # > 15 km: Car
kilometer=float(input("enter kilometer"))

if  kilometer<=3:
    print("walk")
elif kilometer>3 and kilometer<=15:
    print("bike")
else:
    print("car")
# Out:
# enter kilometer 3
# walk

# %%
# 24. Write a Python program to check if a *username* starts with a letter and not a number.

# %%
# 30. Write a Python program to check whether an input string is *empty, **only spaces, or **contains characters*.

# %%
import string
#help(string)

# %%
ascii_lowercase = 'abcdefghijklmnopqrstuvwxyz'
asci_uppercase = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
digits = '0123456789'
punctuation = '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
whitespace = ' \t\n\r\x0b\x0c'

value=input("enter the character:  ")

if len(value) == 1:
    if value in ascii_lowercase:
        print(f"you entered the lower character: { value}")
    elif value in asci_uppercase:
        print(f"you entered the upper character: {value }")
    elif value in digits:
        print(f"you entered the digits: {value }")
    elif value in punctuation:
        print(f"You Entered special character: {value}")
    elif value in whitespace:
        print(f"You Entered white space: {value}")
else:
    print("ivalid length")
# Out:
# enter the character:   #
# You Entered special character: #
