# %% [markdown]
# ### 21. OS Module
#
# Os stand for Operating System
#
# Using os, We can:
#
# > Create folder
#
# > Delete Folder
#
# > Rename files/folder
#
# > Check wheather files/folder exists or not.
#
# > Change directory
#
# > List of files and folder
#
# > Working with virtual environmennt
#
# > Get files information
# > Execute operating-system commands

# %% [markdown]
# ## 2. Current Working Directored

# %%
import os

# %%
print(os.getcwd())
# Out:
# D:\Python2039[Morning8-10AM]

# %% [markdown]
# 3. Change Working Directory

# %%
os.chdir("C://Users//User")
print(os.getcwd())
# Out:
# C:\Users\User

# %% [markdown]
# Linux:
#
# os.chdir("/home/Users/user/")

# %% [markdown]
# ### 5. Created a Dictrectory
#
# os.mkdir()

# %%
os.mkdir("Ankesh")

# %%
os.chdir("D://Python2039[Morning8-10AM]")

# %%
os.getcwd()
# Out:
# 'D:\\Python2039[Morning8-10AM]'

# %%
os.mkdir("Ankesh")

# %% [markdown]
# ### 6. Create Nested Dictionaries

# %%
os.getcwd()
# Out:
# 'D:\\Python2039[Morning8-10AM]'

# %%
import os

# %%
os.makedirs("Python/Django/Project")

# %%
# if One folder

os.mkdir("A")


# Create nested folder

os.makedirs("")

# %%
DateTime
Sys
Os Module

Networking
Paramiko
Netmiko

# %%
# Q. Write a program to find the sum of 1-50, and find the sum of even 1-50 and find the sum of odd - 1-50.


# Q2. Write a program to count total number of vowel, consonent and total characters without space, 
# total Upper character and total lower?

# Sentence= "The Quick Brown Fox Jump Over The Lazy Dog"


# Q3. 

*
**
****
*****
****
***
**
*

1
23
456
78910

1
22
333
4444
55555

# %%
*
**
****
*****
****
***
**
*
# Out:
#   Cell In[16], line 1
#     *
#      ^
# SyntaxError: invalid syntax

# %%
for i in range(1,6):
    print("*"*i)
for j in range(4,0,-1):
    print("*"*j)
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *
