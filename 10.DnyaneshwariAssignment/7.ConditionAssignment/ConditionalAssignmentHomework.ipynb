# %%
## 1 Positive, Negative or Zero
num = int(input("Enter number: "))
if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter number:  5
# Positive

# %%
## 2 Even or Odd
num = int(input("Enter number: "))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter number:  10
# Even

# %%
## 3 Eligible to Vote
age = int(input("Enter age: "))
if age >= 18:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Enter age:  19
# Eligible

# %%
## 4. Largest of Two Numbers
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
if a > b:
    print(a)
else:
    print(b)
# Out:
# Enter first number:  10
# Enter second number:  15
# 15

# %%
## 5. Divisible by 5
num = int(input("Enter number: "))
if num % 5 == 0:
    print("Yes")
else:
    print("No")
# Out:
# Enter number:  25
# Yes

# %%
## 6. Multiple of 3 and 5
num = int(input("Enter number: "))
if num % 3 == 0 and num % 5 == 0:
    print("Yes")
else:
    print("No")
# Out:
# Enter number:  45
# Yes

# %%
## 7. Vowel or Consonant
ch = input("Enter character: ")
if ch in "aeiouAEIOU":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter character:  D
# Consonant

# %%
## 8. Leap Year
year = int(input("Enter year: "))
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")
else:
    print("Not Leap Year")
# Out:
# Enter year:  2008
# Leap Year

# %%
## 9. Number Between 1 to 100
num = int(input("Enter number: "))
if num >= 1 and num <= 100:
    print("Yes")
else:
    print("No")
# Out:
# Enter number:  101
# No

# %%
## 10. Child, Teenager or Adult
age = int(input("Enter age: "))
if age <= 12:
    print("Child")
elif age <= 19:
    print("Teenager")
else:
    print("Adult")
# Out:
# Enter age:  67
# Adult

# %%
# 11. Largest of Three Numbers
a = int(input("First: "))
b = int(input("Second: "))
c = int(input("Third: "))
if a >= b and a >= c:
    print(a)
elif b >= a and b >= c:
    print(b)
else:
    print(c)
# Out:
# First:  15
# Second:  25
# Third:  35
# 35

# %%
# 12. Positive Even, Positive Odd or Negative
num = int(input("Enter number: "))
if num > 0:
    if num % 2 == 0:
        print("Positive Even")
    else:
        print("Positive Odd")
else:
    print("Negative")
# Out:
# Enter number:  19
# Positive Odd

# %%
marks = int(input("Enter Marks: "))

if marks >= 90:
    print("A")
elif marks >= 80:
    print("B")
elif marks >= 70:
    print("C")
elif marks >= 60:
    print("D")
else:
    print("F")
# Out:
# Enter Marks:  76
# C

# %%
# 15. Digit, Uppercase, Lowercase or Special Character
ch = input("Enter character: ")
if ch.isdigit():
    print("Digit")
elif ch.isupper():
    print("Uppercase")
elif ch.islower():
    print("Lowercase")
else:
    print("Special Character")
# Out:
# Enter character:  Dnyanu
# Special Character

# %%
# 16. Century Year
year = int(input("Enter year: "))
if year % 100 == 0:
    print("Century Year")
else:
    print("Not Century Year")
# Out:
# Enter year:  2001
# Not Century Year

# %%
# 17. Triangle Type
a = int(input("Side1: "))
b = int(input("Side2: "))
c = int(input("Side3: "))
if a == b == c:
    print("Equilateral")
elif a == b or b == c or a == c:
    print("Isosceles")
else:
    print("Scalene")
# Out:
# Side1:  200
# Side2:  200
# Side3:  200
# Equilateral

# %%
# 18. Password Check
password = input("Enter password: ")
if password == "python123":
    print("Correct")
else:
    print("Wrong")
# Out:
# Enter password:  dnyanu@123
# Wrong

# %%
# 19. Temperature
temp = int(input("Enter temperature: "))
if temp < 20:
    print("Cold")
elif temp <= 30:
    print("Moderate")
else:
    print("Hot")
# Out:
# Enter temperature:  40
# Hot

# %%
# 20. Multiple of 2, 3, Both or None
num = int(input("Enter number: "))
if num % 2 == 0 and num % 3 == 0:
    print("Both")
elif num % 2 == 0:
    print("2")
elif num % 3 == 0:
    print("3")
else:
    print("None")
# Out:
# Enter number:  18
# Both

# %%
# 21. Discount
amount = float(input("Enter amount: "))
if amount > 1000:
    discount = amount * 20 / 100
elif amount >= 500:
    discount = amount * 10 / 100
else:
    discount = 0
print("Discount =", discount)
print("Final =", amount - discount)
# Out:
# Enter amount:  500
# Discount = 50.0
# Final = 450.0

# %%
# 22. Weekday or Weekend
day = int(input("Enter day (1-7): "))
if day == 6 or day == 7:
    print("Weekend")
elif day >= 1 and day <= 5:
    print("Weekday")
else:
    print("Invalid")
# Out:
# Enter day (1-7):  7
# Weekend

# %%
# 23. Mode of Transport
distance = float(input("Enter distance: "))
if distance < 3:
    print("Walk")
elif distance <= 15:
    print("Bike")
else:
    print("Car")
# Out:
# Enter distance:  250
# Car

# %%
# 24. Username Check
username = input("Enter username: ")
if username[0].isalpha():
    print("Valid")
else:
    print("Invalid")
# Out:
# Enter username:  dnyanu2008
# Valid

# %%
# 25. Electricity Bill
units = int(input("Enter units: "))
if units <= 100:
    bill = units * 1
elif units <= 200:
    bill = units * 1.5
else:
    bill = units * 2
print("Bill =", bill)
# Out:
# Enter units:  15
# Bill = 15

# %%
# 26. Pass or Fail
m1 = int(input("Subject1: "))
m2 = int(input("Subject2: "))
m3 = int(input("Subject3: "))
if m1 >= 40 and m2 >= 40 and m3 >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Subject1:  45
# Subject2:  56
# Subject3:  59
# Pass

# %%
# 27. Leap Century Year
year = int(input("Enter year: "))
if year % 100 == 0 and year % 400 == 0:
    print("Leap Century")
else:
    print("Not Leap Century")
# Out:
# Enter year:  2006
# Not Leap Century

# %%
# 28. Bank Balance
balance = float(input("Enter balance: "))
if balance < 1000:
    print("Low")
elif balance <= 5000:
    print("Medium")
else:
    print("High")
# Out:
# Enter balance:  100000
# High

# %%
# 29. BMI
bmi = float(input("Enter BMI: "))
if bmi < 18.5:
    print("Underweight")
elif bmi < 25:
    print("Normal")
elif bmi < 30:
    print("Overweight")
else:
    print("Obese")
# Out:
# Enter BMI:  22
# Normal

# %%
# 30. Empty, Spaces or Characters
text = input("Enter text: ")
if text == "":
    print("Empty")
elif text.isspace():
    print("Only Spaces")
else:
    print("Contains Characters")
# Out:
# Enter text:  sonwane
# Contains Characters

# %%
## HOMEWORK TASK

## 1. City Monument

city = input("Enter city name: ")

if city == "Delhi":
    print(["Redfort", "QutubMinar", "LotusTemple"])
elif city == "Agra":
    print("TajMahal")
elif city == "Jaipur":
    print("HawaMahal, JalMahal")
elif city == "Amritsar":
    print("GoldenTemple, JalliawalaBagh")
elif city == "Madurai":
    print("Meenakshi Temple")
elif city == "Mysore":
    print("Mysore Palace")
elif city == "Mumbai":
    print("Gateway of India")
elif city == "Sanchi":
    print("Sanchi Stupa")
elif city == "Hyderabad":
    print("Charminar")
elif city == "Gujarat":
    print("Statue of Unity")
else:
    print("City not found")
# Out:
# Enter city name:  Agra
# TajMahal

# %%
## 2. Shop discount

amount = int(input("Enter purchase amount: "))

if amount > 2000:
    print("20% Discount")
elif amount >= 1000:
    print("10% Discount")
else:
    print("No Discount")
    print("Shop more =", 1000 - amount)
# Out:
# Enter purchase amount:  2000
# 10% Discount

# %%
## 3. Employee Bonus

salary = float(input("Enter Salary: "))
years = int(input("Enter Years of Service: "))

if years > 10:
    bonus = salary * 10 / 100
elif years >= 6:
    bonus = salary * 8 / 100
else:
    bonus = salary * 5 / 100

print("Bonus =", bonus)
print("Total Salary =", salary + bonus)
# Out:
# Enter Salary:  50000
# Enter Years of Service:  25
# Bonus = 5000.0
# Total Salary = 55000.0

# %%
## 4. Bike Tax

price = int(input("Enter bike price: "))

if price > 100000:
    print("Tax = 15%")
elif price > 50000:
    print("Tax = 10%")
else:
    print("Tax = 8%")
# Out:
# Enter bike price:  150000
# Tax = 15%

# %%
## 5. Senior Citizen

age = int(input("Enter age: "))

if age >= 60:
    print("Senior Citizen")
else:
    print("Not Senior Citizen")
# Out:
# Enter age:  45
# Not Senior Citizen

# %%
## 6. Positive or Negative

num = int(input("Enter number: "))

if num > 0:
    print("Positive")
elif num < 0:
    print("Negative")
else:
    print("Zero")
# Out:
# Enter number:  08
# Positive

# %%
## 7. Attendance

working = int(input("Working days: "))
absent = int(input("Absent days: "))

present = working - absent
per = present * 100 / working

print(per)

if per >= 75:
    print("Allowed")
else:
    print("Not Allowed")
# Out:
# Working days:  28
# Absent days:  2
# 92.85714285714286
# Allowed

# %%
## 8. Grade

marks = int(input("Enter marks: "))

if marks >= 90:
    print("A")
elif marks >= 80:
    print("B")
elif marks >= 70:
    print("C")
elif marks >= 60:
    print("D")
else:
    print("E")
# Out:
# Enter marks:  76
# C

# %%
## 9. Traffic Light

light = input("Enter light: ")

if light == "Green":
    print("Go")
elif light == "Yellow":
    print("Caution")
elif light == "Red":
    print("Stop")
# Out:
# Enter light:  Red
# Stop

# %%
## 10. User Role

role = input("Enter role: ")

if role == "admin":
    print("Access Granted")
elif role == "Editor":
    print("Can Edit")
elif role == "viewer":
    print("Can View")
else:
    print("Unknown Role")
# Out:
# Enter role:  Editor
# Can Edit

# %%
## 11. Discount

amount = int(input("Enter amount: "))

if amount > 100:
    print("15% Discount")
elif amount > 50:
    print("5% Discount")
else:
    print("No Discount")
# Out:
# Enter amount:  500
# 15% Discount

# %%
## 12. Character Type

ch = input("Enter character: ")

if ch.isupper():
    print("Uppercase")
elif ch.islower():
    print("Lowercase")
elif ch.isdigit():
    print("Digit")
else:
    print("Special Character")
# Out:
# Enter character:  Dnyanu@2008
# Special Character

# %%
## 13. Shape

side = int(input("Enter sides: "))

if side == 3:
    print("Triangle")
elif side == 5:
    print("Pentagon")
elif side == 7:
    print("Septagon")
else:
    print("Other Shape")
# Out:
# Enter sides:  200
# Other Shape

# %%
## 14. Vowel or Consonant

ch = input("Enter character: ")

if ch in "aeiouAEIOU":
    print("Vowel")
else:
    print("Consonant")
# Out:
# Enter character:  Dnyanu
# Consonant

# %%
## Simple calculator

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
op = input("Enter operator: ")

if op == "+":
    print(a + b)
elif op == "-":
    print(a - b)
elif op == "*":
    print(a * b)
elif op == "/":
    print(a / b)
elif op == "^":
    print(a ** b)
else:
    print("Invalid Operator")
# Out:
# Enter first number:  15
# Enter second number:  20
# Enter operator:  *
# 300
