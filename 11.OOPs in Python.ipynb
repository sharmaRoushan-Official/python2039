# %% [markdown]
# ## 11. Class and Object in Python
#
# #### 1. Object-Oriented Programming
#
# #### Q. What is OOP?
# `OOP` is a programming paradigm(An OOP paradigm is a style of coding that built software around object instead of logic) that organize software design around object, rather than function and logic.
#
#
# #### Why OOP:
#
# * Code Reusability
# * Moudularity: [Moudlarity in OOP is the practice of breaking a complex software system into smaller, independent, and self-contained units.]
# * Scalability: [Scalability in Object-Oriented Programming (OOP) means writing modular, flexible code that grows smoothly]
# * Easy Maintainance
# * Real-Wordl Modeling
#
# #### Real-World Analogy
#
# |Real World|Programming|
# |-----|-----|
# |Car|Object|
# |Blueprint|Class|
# |Driving|Method|
# |Fuel Level|Attribute|

# %% [markdown]
# ### 2. Class
# A `Class` is a blueprint or template used to create any object.
#
# syntax

# %%
class Student:
    pass

# %% [markdown]
# ### Key Points:
#
# * Define `class` keyword
# * Can contains variables and method.
# * Naming Case: PascalCase

# %%
class Student:  # Student is the class name 
    def display(self):  # display is the method of Student Class
        print("Welcome to Python OOP") # Statment of method

# %%
obj1 = Student()
obj1.display()
# Out:
# Welcome to Python OOP

# %%
s2 = Student()
s2.display()
# Out:
# Welcome to Python OOP

# %%
id(obj1)
# Out:
# 2236381353968

# %%
id(s2)
# Out:
# 2236379462736

# %% [markdown]
# #### 3. Object
# An `Object` is an instance of a class.
#
# syntax:

# %%
obj1= Student()
obj1.display()
# Out:
# Welcome to Python OOP

# %%
s2 = Student()
s2.display()
# Out:
# Welcome to Python OOP

# %% [markdown]
# #### Key Points
#
# * Memory allocated when object is created.
# * Can access class method and varaibles.
#
# #### 4. Self Keyword
#
# Define:
# `self refers to the current object of the class`
#
# ### ➽ Why Required?
# * To access instance variables and methods
# * Diffrentiate instance variables from local varaibles.

# %%
obj = Student()
obj.display()
# Out:
# Welcome to Python OOP

# %%
id(obj)
# Out:
# 2236379413424

# %%
class Demo:
    def show(self):
        print("Self represent current object.")
Demo()

# %%
obj = Demo()
obj.show()
# Out:
# Self represent current object.

# %% [markdown]
# ### 5. Constructor
#
# A `Constructor` initializes object data autmatically when the objcet is created.
#
#
# syntax:
#
# `def __init__(self):`

# %%
class Student:
    def __init__(self,name,age):
        self.name = name  # instance variable
        self.age = age  # instance varaible

# %%
s1 = Student("Ankesh",65)  # Function invoking
s1.name
# Out:
# 'Ankesh'

# %%
s1.age
# Out:
# 65

# %% [markdown]
# ### Key Points:
# * Automatically invoded
# * Used to initialized instance varaible

# %% [markdown]
# ### Instance, Attribute and Method in Python

# %%
class Student:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def studentDetails(self): # instance method 
        print("Student Name:",self.name)
        print("Student Age:",self.age)
obj = Student("Ankesh",13)
# print(obj.name)
# obj.age
obj.studentDetails()
# Out:
# Student Name: Ankesh
# Student Age: 13

# %%
class Student:
    def __init__(ankesh,name,age):
        ankesh.name = name
        ankesh.age = age

    def studentDetails(ankesh): # instance method 
        print("Student Name:",ankesh.name)
        print("Student Age:",ankesh.age)
        
obj = Student("Ankesh",13)
# print(obj.name)
# obj.age
obj.studentDetails()
# Out:
# Student Name: Ankesh
# Student Age: 13

# %% [markdown]
# ### 1. Class
#
# A __class__ is blueprint(template) used to create objects.
#
#
#     class Student:
#
#         class Name: `Student`
# ----
# ### 2. Instance(Object)
#
# An __instance__(also called an object) is a real objected created from a class.
#
# obj = Student("Ankesh",13)
#
# Here,
#   * `obj` is the instance(object) of the `Student` class.
#
# ----
#
# ### 3. Attributes(Instance Varaible)
#
#     Attributes are variables that belong to an object.
#
#    self.name = name
#    self.age = age
#
# Here,
#   * `self.name`➼Attribute(Instance variable)
#   * `self.age`➼Attribute(Instance Variable)
#
# ----
# ### 4. Instance Method
#
# An __instance method__ is a method that works with an object and has `self` as its first parameter.
#
# ```def studentDetails(self):```
#
# It accesses the object's attribute using self.
#
# Called as:
#
# `obj.studentDetails()`
#
# Output:
#  * Student Name: Ankesh
#  * Student Age: 13
# ---
# ### 5. Constructor
#
# An __constructor__ is a special method that is automatically called when object is created.
#
# `def __init__(self,name,age):`
#
# Purpose:
#  * Initializes the object.
#  * Assign values to the instance varaible(attribute)
# ----
# ### 6. Self Keyword
# `self` refers to the current object(instance).
#
# When Python executes
#
# `obj.studentDetails()`
#
# Python automaticlaly converts it to
#
# `Student.studentDetails(obj)`
#
# so,
#  * self = obj

# %%
obj.studentDetails()
# Out:
# Student Name: Ankesh
# Student Age: 13

# %%
Student.studentDetails(obj)
# Out:
# Student Name: Ankesh
# Student Age: 13

# %%
obj1 = Student("Praveen",65)
obj1.studentDetails()
# Out:
# Student Name: Praveen
# Student Age: 65

# %%
Student.studentDetails(obj1)
# Out:
# Student Name: Praveen
# Student Age: 65

# %%
Student.studentDetails(obj)
# Out:
# Student Name: Ankesh
# Student Age: 13

# %%
class Student:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def studentDetails(self): # instance method 
        print("Student Name:",self.name)
        print("Student Age:",self.age)
        
obj = Student("Ankesh",13)
# print(obj.name)
# obj.age
obj.studentDetails()
# Out:
# Student Name: Ankesh
# Student Age: 13

# %% [markdown]
# ### Summary Table
#
# |Term|In This Program|
# |----|-----|
# |class|Student|
# |Instance/Object|obj|
# |Attribute(Instance Variable)|`self.name`,`self.age`|
# |constructor|`__init__()`|
# |Instance Method|studentDetails()|
# |self| Refers to the current object|
#
#
# ------
# Real-Life Example
#
# * Imagine __Student Admission form__
#
#  * class ➽ Student Admission form(Bluprint)
#
#  * Instance/Object ➽ One actual Student (Ankesh)
#
#  * Attribute ➽ Student's Name and age.
#
#  * Method ➽ Display Student Details

# %% [markdown]
# # Pillars of OOPs
# -----------
#
# # ➥ There are 4 Pillars of OOPs
#
# #### ➤ 1. Inheritance
#  * ★ 1. Single/Simple Inheritance
#  * ★ 2. Multiple Inheritance
#  * ★ 3. Multilevel Inheritance
#  * ★ 4. Hierarchical Inheritance
#  * ★ 5. Hybrid Inheritance
# #### ➤ 2. Encapsulation [Wrapping up of data]
#  * Access Modifiers
#     * ★ Public: (x)
#     * ★ Protected: (_x)
#     * ★ Private: (__x)
# #### ➤ 3. Polymorphism [one method has many forms]
#  * Method Overloading: Method Name Same Different Parameter
#  * Method Overriding: Same signature: Same method name and Same parameter
#  * Operator Overloading
#  * Duck Typing
# #### ➤ 4. Data Abstraction: [Data Hiding]
#  * __Module:__ from abc import ABC, abstractmethod
#
#
# ### `Super().__init__`

# %% [markdown]
# # ➤ 1. Inheritance
#
# #### 1. Single/Simple Inheritance
# Meaning:
#
# * In `Single Inheritance`, a child inherits from one one parent class.
#
# 📌 Structure
# `Parent ➽ Child`
#
# #### Why it is used:
#  * Code reusability
#  * Child class can use parent class properties and method.
#  * Easy to userdstand and maintain
#
# #### Real-Life Example
#
# * Parent - Vehicle
# * Child - Car
#
# `A Var is a Vehicle`

# %%
class Vehicle:  # parent class
    def start(self):
        print("Vehicle Started.")


class Car(Vehicle):  # Child / Derived Class
    def drive(self):
        print("Car is Driving.")


# v = Vehicle()
# v.start()

# c = Car()
# c.drive()


c = Car()
c.start()  # start is the method of parent class
c.drive()  # drive is the method of child class
# Out:
# Vehicle Started.
# Car is Driving.

# %% [markdown]
# Note:
# Single Inheritance is most basic and safest inheritance. It avoids Complixity and ambiguity.
#
# [Ambiguity in Object-Oriented Programming (OOP) occurs when a compiler or program cannot decide which function, variable, or path to choose]

# %% [markdown]
# ### ★ 2. Multiple Inheritance
# Meaning
#
# In `Multiple Inheritance`,a child class inherits from more than one parent class.
#
# 📌 Structure
#
# ```text
#     Parent1           Parent2
#         \              /
#          \            /
#           \          /
#              Child
# ```
#
# ### Why It is used?
#  * When one class needs feature of multiple classes.
#  * Helps to combine functionlity.
#
# ### Real-Life Example
#  * Parent1: Camera
#  * Parent2: Phone
#  * Child: SmartPhone
#
# `SmartPhone is both a Phone and a Camera`
#
# Python Example

# %%
class Camera: # Parent 1
    def click_photo(self):
        print("Photo Clicked......")


class Phone:  # Parent 2
    def calling(self):
        print("Calling......")


class SmartPhone(Camera,Phone): # Derived class : Parent1 + Parent2
    def internet(self):
        print("Google Connected")


obj = SmartPhone()
obj.click_photo()
obj.calling()
obj.internet()
# Out:
# Photo Clicked......
# Calling......
# Google Connected

# %% [markdown]
# Note:
#
# Python support multiple inheritance, you can check order of method called Method Resoluction Order(MRO) to avoid confustion.

# %%
print(SmartPhone.mro())
# Out:
# [<class '__main__.SmartPhone'>, <class '__main__.Camera'>, <class '__main__.Phone'>, <class 'object'>]

# %% [markdown]
# ### ★ 3. Multilevel Inheritance
#
# Meaning
#
# In `Multilevel Inheritance`, inheritance happens in levels.
#
#
# 📌 Structure
#
# `Grandparent ➽ Parent ➽ Child`
#
# #### Why it is used?
#  * To represent hierarchy in real world.
#  * Step-by-step Inheritance of feature.
#
# #### Real-Life Example
#
#  * Grandparent: Animal
#  * Parent: Mammal
#  * Child: Dog
#
# `Dog is a Mammal, Mammal is an Animal`

# %%
class Animal:
    def eat(self):
        print("Eating......")

class Mammal(Animal):
    def walk(self):
        print("Walking")

class Dog(Mammal):
    def bark(self):
        print("Barking....")


d = Dog()
d.eat() # eat is the method of animal
d.walk() # walk is the method of mammal
d.bark() # bark is the mehtod of dog.
# Out:
# Eating......
# Walking
# Barking....

# %%
print(Dog.mro())
# Out:
# [<class '__main__.Dog'>, <class '__main__.Mammal'>, <class '__main__.Animal'>, <class 'object'>]

# %% [markdown]
# ### ★ 4.Hierarchical Inheritance
#
# Meaning
#
# In `Hierarchical Inheritance,`, Multiple classes inherits from a single parent.
#
#
# 📌 Structure
#
# ```text
#
#        Parent1
#       /   |   \
#      /    |    \
#     /     |     \
#  child1  child2  child3
#  ```
#
# ### Why it is used?
# * One parent has common functionality.
# * Different children use and extend it differently.
#
# #### Real-Life Example:
# * Parent: Employee
# * Children:
#      * Manager
#      * Developer
#      * Tester
# * All are employees but have different roles.
#
#  Python Example

# %%
class Employee:
    def work(self):
        print("Employee is working..........")

class Manager(Employee):
    def manage(self):
        print("Manager is Managing.......")

class Developer(Employee):
    def code(self):
        print("Developer is coding..........")
        
class Tester(Employee):
    def test(self):
        print("Tester is testing............")

m = Manager()
m.work()  # work() is the method of parent class
m.manage() # manage() is the method of Manager.

d = Developer()
d.work() # work() is the method of parent class.
d.code() # code() is the method of Developer class

t = Tester()
t.work() # work() is the method of parent class.
t.test() # test() is the method of Tester() class
# Out:
# Employee is working..........
# Manager is Managing.......
# Employee is working..........
# Developer is coding..........
# Employee is working..........
# Tester is testing............

# %%
print(Manager.mro())
# Out:
# [<class '__main__.Manager'>, <class '__main__.Employee'>, <class 'object'>]

# %%
print(Developer.mro())
# Out:
# [<class '__main__.Developer'>, <class '__main__.Employee'>, <class 'object'>]

# %%
print(Tester.mro())
# Out:
# [<class '__main__.Tester'>, <class '__main__.Employee'>, <class 'object'>]

# %% [markdown]
# Note:
# This is very common in software systems.
# (Banking,College System,EMS)

# %% [markdown]
# #### ★ 5. Hybrid Inheritance
#
# meaning
#
# Hybrid Inheritance is combination of two or more inheritance type.
#
# It may Include:
# * Multiple+Hierarchical
# * Hierarchical+Multilevel
#
# ```text
#           A
#         /   \
#        B     C
#         \   /
#           D
# ```
# Here,
# * B and C inherits from A(Hierarchcal Inheritance)
# * D inherits from B and C(Multiple Inheritance)
#
# ### Why it is used?
# * When a system requires complex Inheritance.
# * Common in large framework and enterprises
#
# Python Example

# %%
class A:
    def showA(self):
        print("Class A")
class B(A):
    def showB(self):
        print("Class B")
class C(A):
    def showC(self):
        print("Class C")
class D(B,C):
    def showD(self):
        print("Class D")


obj = D()
obj.showA()
obj.showB()
obj.showC()
obj.showD()
# Out:
# Class A
# Class B
# Class C
# Class D

# %% [markdown]
# Note:
#
# Hybrid Inheritance is powerful but can cause confusion
#
#  * Method Conflict
#  * ambiguity

# %%
print(D.mro())
# Out:
# [<class '__main__.D'>, <class '__main__.B'>, <class '__main__.C'>, <class '__main__.A'>, <class 'object'>]

# %% [markdown]
# ### Key Points
#
# ##### ✅ Benefits of inheritance
#  * ◉ Code Reusability
#  * ◉ Easy maintainance
#  * ◉ Faster Development
#  * ◉ Supports polymorphism
#  * ◉ Improve modular design
#
# ##### ⚠️ Common Confusion to Clearify
#  * ◉ Difference between Multiple vs Multilevel
#  * ◉ Hybrid inheritance is not a separate mechanism, it is just a combination
#  * ◉ Python resolve multiple inheritance using mro
#
# ##### Summary Table
#
# |__Type__|__Meaning__|__Example__|
# |---|---|---|
# |`Single/Simple`|One Parent ➼ One Child| A➼B|
# |`Multiple`|Many Parent ➼ One Child| A,B ➼ C|
# |`Multilevel`|Inhertis in levels|A➼B➼C|
# |`Hierarchical`|One Parent ➼ Many Children|A➼B,C,D|
# |`Hybrid`|Combinatio of Multipe types| (A➼B,C) and (B,C➼D)|

# %% [markdown]
# ### 2. Polymorphism
#
# Meaning of Polymorphism
#
# `Polymorphism` means __"Many Morms"__
#
# In OOP, the same method name behaves differently depending on the object that call it.
#
#
# 📌 Simple Definition
# > One function or method, but multiple behaviors.
#
# ##### Why Polymorphism is Important.
#
# * Code become flexible.
# * Code become resusable
# * Supports real-world scenarios
# * Make program easy to extend
# * Reduces code duplication
#
# ### Real-Life Analogy
#
# Example: Person roles
#
# * A person can be:
#    * Employee
#    * Developer
#    * Team Lead
#    * Tester
#
# Note: Same person, different behavior based on role this is called `Polymorphism`.
#
#
# #### Types of Polymorphism
#
# 1. Method Overloading(Conceptual in Python) (Same Method or Function but different parameter)
# 2. Method Overriding(Same Method and same parameter: Same Signature) (Runtime Polymorphism)
# 3. Polymorphism using Inheritance
# 4. Polymorphism using Duck typing
# 5. Operator Overloading: [+ symbol]
#    `*args and **kwargs`

# %% [markdown]
# #### 1. Method Overloading(Conceptual in Python) (Same Method or Function but different parameter)
#
# Python does not support traditional overloading, but we can achiever using default argument.

# %%
class Calculator:
    def add(self, a,b=0,c=0):  #  3 parameters 
        return a+b+c # 5+6+0


obj1 = Calculator()
print(obj1.add(5,))  # 1 parameter
print(obj1.add(5,6,)) # 2 parameter
print(obj1.add(1,2,3))  # 3 parameter
# Out:
# 5
# 11
# 6

# %% [markdown]
# ### Keypoints:
# * Same method name add
# * Different numbers of arugment
# * Behavior changes automatically according to value.

# %% [markdown]
# ### 2. Method Overriding(Same Method and same parameter: Same Signature) (Runtime Polymorphism)
#
# Child class provides its own implementation of parent method

# %%
class Employee:
    def role(self):
        return "I am an Employee."

class Developer(Employee):
    def role(self):
        return "I am Developer."

class TeamLead(Developer):
    def role(self):
        return "I am a Team Leader"

# obj = Developer()
# obj.role()

obj1 = TeamLead()
obj1.role()
# Out:
# 'I am a Team Leader'

# %% [markdown]
# ### Keypoints:
#
# * Same Method Name role()
# * Different Output
# * Based on object type
# * Runtime Polymorphism

# %%
e = Employee()
print(e.role())

d = Developer()
print(d.role())

t = TeamLead()
print(t.role())
# Out:
# I am an Employee.
# I am Developer.
# I am a Team Leader

# %% [markdown]
# ### 3. Polymorphism using Inheritance

# %%
class Shape:
    def area(self):
        pass

class Rectangle(Shape):
    def area(self):
        return "Area: Length*Width"

class Circle(Shape):
    def area(self):
        return "Area: pi*r**2"

# %%
shapes = [Rectangle(), Circle()]

for shape in shapes:
    print(shape.area())
# Out:
# Area: Length*Width
# Area: pi*r**2

# %% [markdown]
# #### 4. Polymorphism using Duck Typing
#
# 📌 Rule:
#
# > If it looks like a duck and quacks like a duck, it is duck.
#
# Example

# %%
class Developer:
    def work(self):
        print("Developer Devloping Code")

class TeamLead:
    def work(self):
        print("Team Lead Managing Team.")


def do_work(person): # person = TeamLead()
    person.work()  # .work()

# %%
do_work(Developer())
# Out:
# Developer Devloping Code

# %%
do_work(TeamLead())
# Out:
# Team Lead Managing Team.

# %%
class Developer:
    def work(self):
        print("Developer Devloping Code")


Developer().work()
# Out:
# Developer Devloping Code

# %%
class TeamLead:
    def work(self):
        print("Team Lead Managing Team.")


TeamLead().work()
# Out:
# Team Lead Managing Team.

# %%
obj = TeamLead()
obj.work()
# Out:
# Team Lead Managing Team.

# %%
TeamLead().work()
# Out:
# Team Lead Managing Team.

# %% [markdown]
# Notes:
#
# * No inheritance needed.
# * Method name matter. `work()`
# * Python's dynmaic nature

# %% [markdown]
# ### 5. Operator Overloading `+`
#
# Same Operator behave differently for different data types.

# %%
print(10+20)
print(10+20+30)
print("ankesh"+" "+"Yadav")
print([10,20]+[10,30])
print((10,45)+(80,90))
# Out:
# 30
# 60
# ankesh Yadav
# [10, 20, 10, 30]
# (10, 45, 80, 90)

# %% [markdown]
# Notes:
# ----
# |Operator|Behavior|
# |----|-----|
# |`+`|Add numbers|
# |`+`|Concatenate strings|
# |`+`|Merge lists|
# |`+`|Merge Tuples|

# %%
x = list((10,30))
print([10,20]+x)
print((10,45)+(80,90))
# Out:
# [10, 20, 10, 30]
# (10, 45, 80, 90)

# %%
list((10,20))
# Out:
# [10, 20]

# %% [markdown]
# ### Important Points:
#
# ----
# * ꪜPolymorphism is runtime behavior.
# * ꪜAchieved using inheritance & overriding.
# * ꪜPython supports dynamic polymorphism.
# * ꪜDuck typing is unique.
#
# -----
# One-Line Summary
# > Polymorphism allows the same method name and same parameter to perform different action based on their object calling.

# %%
def calculate(*args):
    return sum(args)

# %%
calculate(10)
# Out:
# 10

# %%
calculate(10,20)
# Out:
# 30

# %%
calculate(10,20,30)
# Out:
# 60

# %%
calculate(10,20,30,40)
# Out:
# 100

# %%
def studentDetails(**kwargs):
    return kwargs

obj1 = studentDetails(name="Swadhin")
print(obj1)
# Out:
# {'name': 'Swadhin'}

# %%
obj1 = studentDetails(name="Swadhin",age=35)
print(obj1)
# Out:
# {'name': 'Swadhin', 'age': 35}

# %%
obj1 = studentDetails(name="Swadhin",age=35,add="Pune")
print(obj1)
# Out:
# {'name': 'Swadhin', 'age': 35, 'add': 'Pune'}
