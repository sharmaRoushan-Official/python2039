# %% [markdown]
# ## Start

# %% [markdown]
# ### Q 1. Create a base class Animal with a method speak(). Create two subclasses Dog and Cat that override speak() and print different sounds.

# %%
class Animal:
    def speak(self):
        print("Animal makes a sound")
class Dog(Animal):
    def speak(self):
        print("Dog barks: woof woof")
class Cat(Animal):
    def speak(self):
        print("Cat barks: meow meow")
obj = Animal()
obj.speak()
obj2 = Dog()
obj2.speak()
obj1 = Cat()
obj1.speak()
# Out:
# Animal makes a sound
# Dog barks: woof woof
# Cat barks: meow meow

# %% [markdown]
# ### Q 2. Create a class Vehicle with attributes brand and model. Create subclasses Car and Bike that add a method vehicle_type() returning the type of vehicle.

# %%
class Vehicle:
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model
class Car(Vehicle):
    def vehicle_type(self):
        print (f" This is a car Brand:{self.brand}")
        print (f" This is a car model:{self.model}")
class Bike(Vehicle):
    def vehicle_type(self):
        print (f" This is a bike Brand:{self.brand}")
        print(f" This is a bike model:{self.model}")

# %%
obj = Car("maruti", "swift")
obj.vehicle_type()
obj1 = Bike("Honda", "Shine")
obj1.vehicle_type()
# Out:
#  This is a car Brand:maruti
#  This is a car model:swift
#  This is a bike Brand:Honda
#  This is a bike model:Shine

# %% [markdown]
# ### Q 3. Create a class Person with name and age. Create a derived class Student that adds student ID and grade. Write a method to print complete details.

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
class student(Person):
    def __init__(self, name , age ,student_id, grade):
        super().__init__(name, age)
        self.student_id = student_id
        self.grade = grade
    def student_details(self):
        print(f"Name: {self.name}")
        print(f"Age : {self.age}")
        print(f"Student ID: {self.student_id}")
        print(f"Grade: {self.grade}")
        
obj = student("Riya", 20, "s1", "A")
obj.student_details()
# Out:
# Name: Riya
# Age : 20
# Student ID: s1
# Grade: A

# %% [markdown]
# ### Q 4.Demonstrate *multilevel inheritance* using classes A → B → C, each with a method. Call all three methods from an object of class C.

# %%
class A:
    def showA(self):
        print("This is method from class A")
class B(A):
    def showB(self):
        print("This is method from class B ")
class C(B):
    def showC(self):
        print("This is method from class C")
obj=C()
obj.showA()
obj.showC()
obj.showC()
# Out:
# This is method from class A
# This is method from class C
# This is method from class C

# %% [markdown]
# ### Q 5.Create a parent class Shape with a method area(). Derive classes Circle and Rectangle. Implement the area method in each subclass.

# %%
class Shape:
    def area(self):
        print(f"claculate area of shape")
class Circle(Shape):
    def area(self):
        print (f"Circle Area: pi*r**2")
class Rectangle(Circle):
    def area(self):
        print (f"Rectangle Area:length*width")
obj = Shape()
obj.area()

obj1 = Circle()
obj1.area()

obj2 = Rectangle()
obj2.area()
# Out:
# claculate area of shape
# Circle Area: pi*r**2
# Rectangle Area:length*width

# %% [markdown]
# ### Q 6. Write a function display_info(obj) that calls obj.info(). Pass objects of two different classes having an info() method to demonstrate polymorphism.

# %%
class Teacher:
    def __init__(self, name, subject):
        self.name = name
        self.subject = subject
    def info(self):
        print(f"Teacher Name: {self.name}")
        print(f"Subject: {self.subject}")
class Student:
    def __init__(self, name,roll_no):
        self.name = name
        self.roll_no = roll_no
    def info(self):
        print(f"Student Name: {self.name}")
        print(f"Roll No: {self.roll_no}")
def display_info(obj):
    obj.info()

t1 = Teacher("Mr.sharma","python")
display_info(t1)
s1 = Student("Riya", 101)
display_info(s1)
# Out:
# Teacher Name: Mr.sharma
# Subject: python
# Student Name: Riya
# Roll No: 101

# %% [markdown]
# ### Q 7. Create two classes Dog and Cat with a method sound(). Write a loop that iterates through objects of both classes and calls sound() using polymorphism.

# %%
class Dog:
    def sound(self):
        print("Dog: woof woof")
class Cat:
    def sound(self):
        print("Cat: meow meow")

animals = [Dog(),Cat()]

for animal in animals:
    animal.sound()
# Out:
# Dog: woof woof
# Cat: meow meow

# %% [markdown]
# ### Q 8. Demonstrate *operator overloading* by overloading the + operator for a class Point(x, y) to add coordinates.

# %%
class Point:
    def __init__(self, x ,y):
        self.x = x
        self.y = y
        
    def __add__(self, other):
        new_x = self.x = other.x
        new_y = self.y = other.y
        return Point(new_x, new_y)
        
    def __str__(self):
        return f"({self.x}, {self.y})"
        
p1 = Point(2, 3)
print(f"X:", p1)

p2 = Point(4, 5)
print(f"Y:", p2)

obj = p1 + p2
print(f"Add:", obj)
# Out:
# X: (2, 3)
# Y: (4, 5)
# Add: (4, 5)

# %% [markdown]
# ### Q 9. Create a class Employee and override its __str__() method to print custom details when the object is printed

# %%
class Employee:
    def str(self):
        return f" I am an Employee"
        
class Developer(Employee):
    def str(self):
        return f" I am an Developer"
        
class Tester(Developer):
    def str(self):
        return f" I am an Tester"
        
obj = Employee()
print(obj.str())

obj1 = Developer()
print(obj1.str())

obj2 = Tester()
print(obj2.str())
# Out:
#  I am an Employee
#  I am an Developer
#  I am an Tester

# %% [markdown]
# ### Q 10. Implement method overriding: Parent class Bank has rate_of_interest(). Child classes SBI and HDFC override the method with different interest rates.

# %%
class Bank:
    def rate_of_interest(self):
        print("Bank of interest rate: Defult")

class SBI(Bank):
    def rate_of_interest(self):
        print("SBI: 6.5%")

class HDFC(SBI):
    def rate_of_interest(self):
        print("HDFC: 7.0%")

obj = Bank()
obj.rate_of_interest()

obj1 = SBI()
obj1.rate_of_interest()

obj2 = HDFC()
obj2.rate_of_interest()
# Out:
# Bank of interest rate: Defult
# SBI: 6.5%
# HDFC: 7.0%

# %% [markdown]
# ### Q 11. Create a class Account with private attributes __balance. Provide methods deposit() and withdraw() to modify it safely.

# %%
class Account:
    def __init__(self, balance =0):
        self.__balance = balance
        
    def deposit(self, amount): 
        if amount > 0:
            self.__balance += amount
            print(f"₹{amount} deposited: New Balance: ₹{self.__balance}")
        else:
            print("Amount must be positive")
            
    def withdraw(self, amount):
        if amount > 0:
            if amount <= self.__balance:
                self.__balance -= amount
                print(f"₹{amount} withdraw New Balance: ₹{self.__balance}")
            else:
                print("Infficient Balance")
        else:
            print("Amount mast be positive")
    
    def get__balance(self):
        return self.__balance

acc = Account(1000)

acc.deposit(500)
acc.withdraw(200)
acc.withdraw(1500)
print("Current Balance:", acc.get__balance())
# Out:
# ₹500 deposited: New Balance: ₹1500
# ₹200 withdraw New Balance: ₹1300
# Infficient Balance
# Current Balance: 1300

# %% [markdown]
# ### Q 12.Write a class with a private method __calculate_salary() and a public method get_salary() that internally calls the private method.

# %%
class Employee:
    def __init__(self, name, salary, bonus):
        self.name = name
        self.salary = salary
        self.bonus = bonus
    def __calculate_salary(self):
        total = self.salary + self.bonus
        return total
    def get_salary(self):
        salary = self.__calculate_salary()
        print(f"{self.name} total salary: ₹{salary}")
emp1 = Employee(f"Rahul", 40000, 50000)
emp1.get_salary()
emp2 = Employee(f"Priya", 60000, 100000)
emp2.get_salary()
# Out:
# Rahul total salary: ₹90000
# Priya total salary: ₹160000

# %% [markdown]
# ### Q 13.Create a class Student with private attributes __marks. Write a method to set marks (with validation: marks must be 0–100).

# %%
class student:
    def __init__(self):
        self.__marks = 0
        
    def set_marks(self, marks1):
        if 0  <= marks1 <= 100:
            self.__marks = marks1
            print(f" Your mark is updated: {marks1}")
        else:
            print(f"Invalid! {marks1} is grater than 100")
            
        def get_marks(self):
                return f"your current marks: {self.__marks}"
s1 = student()
s1.set_marks(120)
s1.set_marks(85)
# Out:
# Invalid! 120 is grater than 100
#  Your mark is updated: 85

# %% [markdown]
# ### Q 14.Create a class Product with a private attribute __price. Use getter and setter methods to access and update price.

# %%
class Product:
    def __init__(self, name, price):
        self.name = name
        self.__price = price
        
    def get_price(self):
        return  self.__price
        
    def set_price(self, new_price):
        if new_price > 0:
            self.__price = new_price
            print(f"{self.name} price is updated: {new_price}")
        else:
            print(f" Invalid price ")

    

obj = Product("Laptop", 50000)
print(f"current price: {obj.get_price()}")
obj.set_price(45000)
print(f"New price: {obj.get_price()}")
# Out:
# current price: 50000
# Laptop price is updated: 45000
# New price: 45000

# %% [markdown]
# ### Q 15.Create a class with a protected attribute _data and a child class that modifies and prints the protected attri

# %%
class Parent:
    def __init__(self, data):
        self._data = data
        
    def showp_data(self):
        print(f"parent data: {self._data}")
    
class Child(Parent):
    def __init(self, data):
        super().__init__(data)
        
    def modify_data(self, child_data):
        self._data = child_data
        print(f"modified data: {self._data}")

    def showc_data(self):
        print(f"child data: {self._data}")
    

obj = Child(10)
obj.showp_data()
obj.modify_data(25)
obj.showc_data()
# Out:
# parent data: 10
# modified data: 25
# child data: 25

# %% [markdown]
# ### Q 16.Create an abstract class Vehicle with an abstract method start(). Implement it in subclasses Car and Bike.

# %%
from abc import ABC, abstractmethod

# %%
class Vehicle(ABC):

    @abstractmethod
    def start(self):
        pass

class Car(Vehicle):
    def start(self):
        print("Car is started...")
        
class Bike(Vehicle):
    def start(self):
        print("Bike is started...")
obj = Car()
obj.start()
obj1 = Bike()
obj1.start()
# Out:
# Car is started...
# Bike is started...

# %% [markdown]
# ### Q 17.Create an abstract class Shape with abstract methods area() and perimeter(). Implement these in Circle and Square

# %%
from abc import ABC, abstractmethod
import math

# %%
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass
    @abstractmethod
    def perimeter(self):
        pass
        
class Circle(Shape):
    def __init__(self, redius):
        self.redius = redius
    def area(self):
        return math.pi * self.redius 
    def perimeter(self):
        return 2 * math.pi * self.redius
        
class Square(Shape):
    def __init__(self,side):
            self.side = side
    def area(self):
        return self.side * self.side
    def perimeter (self):
        return 4 * self.side

obj = Circle(5)
print(obj.area())
print(obj.perimeter())
obj1 =Square(4)
print(obj1.area())
print(obj1.perimeter())
# Out:
# 15.707963267948966
# 31.41592653589793
# 16
# 16

# %% [markdown]
# ### Q 18.Define an abstract class FileHandler with methods read() and write(). Create child classes TextFileHandler and BinaryFileHandler

# %%
from abc import ABC, abstractmethod

# %%
class FileHandler(ABC):
    def __init__(self,filename):
        self.filename = filename
        fileName= r"C:\\Users\\ADMIN\\Desktop\\twinkle.txt"
    
    @abstractmethod
    def read(self):
        pass

    @abstractmethod
    def write(self,data):
        pass

class TextFileHandler(FileHandler):

    def read(self):
        with open(self.filename, 'r') as file:
            return file.read()
        
            
    def write(self,data):
         with open(self.filename, 'w') as file:
             file.write(data)
         print(f"text written to{self.filename}")
        

class BinaryFileHandler(FileHandler):
    def read(self):
        with open(self.filename, 'rb') as file:
            return file.read()
       
            
    def write(self,data):
        with open(self.filename, 'rb') as file:
            file.write()
        print(f"binary written to{self.filename,}")

objT=TextFileHandler("test.txt")
print(objT.read())
print(objT.write("hello world"))
objB=BinaryFileHandler("test.bin")
print(objB.read())
print(objB.write("hello world"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 39
#      35             file.write()
#      36         print(f"binary written to{self.filename,}")
#      37
#      38 objT=TextFileHandler("test.txt")
# ---> 39 print(objT.read())
#      40 print(objT.write("hello world"))
#      41 objB=BinaryFileHandler("test.bin")
#      42 print(objB.read())
#
# Cell In[20], line 17, in TextFileHandler.read(self)
#      16     def read(self):
# ---> 17         with open(self.filename, 'r') as file:
#      18             return file.read()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test.txt'

# %% [markdown]
# ### Q 19.Create an interface-like abstract class Remote with methods power_on() and power_off(). Implement it for TV and AC classes.

# %%
from abc import ABC, abstractmethod

# %%
class Remote(ABC):
    @abstractmethod
    def power_on(self):
        pass

    @abstractmethod
    def power_off(self):
        pass

class TV(Remote):
    def power_on(self):
        return f"tv switch on"

    def power_off(self):
        return f"tv switch off"

class AC(Remote):
    
    def power_on(self):
        return f"ac switch on"
        
    def power_off(self):
         return f"ac switch off"
obj=TV()
print(obj.power_on())
print(obj.power_off())
obj1=AC()
print(obj1.power_on())
print(obj1.power_off())
# Out:
# tv switch on
# tv switch off
# ac switch on
# ac switch off

# %% [markdown]
# ### Q 20.Implement an abstract class Payment with method make_payment(). Create subclasses CardPayment, UPIPayment, and WalletPayment with different implementations.

# %%
from abc import ABC, abstractmethod

# %%
class Payment(ABC):
    @abstractmethod
    def make_payment(self,amount):
        pass

class CardPayment(Payment):
    def make_payment(self,amount):
        return f"paid Rs.{amount} Card Payment"

class UPIPayment(Payment):
    def make_payment(self,amount):
        return f"paid Rs.{amount} UPI"

class WalletPayment(Payment):
    def make_payment(self,amount):
        return f"paid Rs. {amount} Wallet"

obj1 = CardPayment()
print(obj1.make_payment(1000))
obj2 = UPIPayment()
print(obj2.make_payment(500))
obj3 = WalletPayment()
print(obj3.make_payment(100))
# Out:
# paid Rs.1000 Card Payment
# paid Rs.500 UPI
# paid Rs. 100 Wallet

# %% [markdown]
# ## END
