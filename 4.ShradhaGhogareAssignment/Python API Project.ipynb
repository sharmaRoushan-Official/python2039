# %% [markdown]
# ### API Project

# %%
def getweather():
    api_keys="4ab3399a294f2a64cb1ad9a5350f8fb9"
    cityName = "Pune"
    url =f"https://api.openweathermap.org/data/2.5/weather?q={cityName}&appid={api_keys}"
    #print(url)
    response = request.get(url)
    print(response)

    if response.status_code == 200:
        data = response.json()
        print(data)

        print(f"==========Temperture Details {cityName}==========")
        temp = data['main']['temp']
        #print (temp)
        temperture = temp -273.15
        print("Current Temperture:",temperture,"°C")



getweather()
# Out:
# https://api.openweathermap.org/data/2.5/weather?q=Pune&appid=4ab3399a294f2a64cb1ad9a5350f8fb9

# %%
import requests
import datetime

# %%
def getweather():
    api_keys="4ab3399a294f2a64cb1ad9a5350f8fb9"
    cityName = "delhi"
    url =f"https://api.openweathermap.org/data/2.5/weather?q={cityName}&appid={api_keys}"

    
    response = requests.get(url)
    print(response)

    
    if response.status_code == 200:
        data = response.json()
        print(data)

        
        print(f"==========Temperture Details {cityName}==========")
        temp = data['main']['temp']
        temperture = temp -273.15
        print("Current Temperture:",temperture,"°C")

        
        print(f"==========Feels like==========")
        T = temperture
        WS = data ['wind']['speed']*3.6

        feels_like = 13.12 + 0.6215*T - 11.37*(WS**0.16) + 0.3965*T*(WS**0.16)
        print(f"current Feels Like:{feels_like:}°C")

        
        print(f"===========Temp Min===========")
        temp_min = data ['main']['temp_min'] - 273.15
        print(f"Current Temp Min: {temp_min:}°C")  

        
        print(f"==========Temp Max===========")
        temp_max = data ['main']['temp_max'] - 273.15
        print(f"Current Temp Max: {temp:}°C")

        print(f"======pressure======")
        pressure = data['main']['pressure']
        print(f"Pressure: {pressure}")

        
        print(f"==========Humidity==========")
        humidity = data['main']['humidity']
        print(f"Current Humidity: {humidity}%")

        
        print(f"=========Country=========")
        country = data['sys']['country']
        print(f"Country: {country}")

        
        print(f"========Visibility========")
        visibility = data['visibility']
        print(f"Visibility:  {visibility}")
        

        print(f"==========Sunrise========")
        sunrise = data['sys']['sunrise']
        print(f"Sunrise: {sunrise}")

        
        print(f"---------sunset==========")
        sunset = data['sys']['sunset']
        print(f"Sunset: {sunset}")

        
        print(f"=======TimeZone========")
        timezone = data['timezone']
        print(f"TimeZone:  {timezone}")

        
        print(f"======id======")
        id = data ['id']
        print(f"ID:  {id}")

        
        print(f"=====name=====")
        name = data ['name']
        print(f"Name:  {name}")  
        
        
        print(f"======cod=======")
        cod = data ['cod']
        print(f"cod: {cod}")
        


        
        
        
getweather()
# Out:
# <Response [200]>
# {'coord': {'lon': 77.2167, 'lat': 28.6667}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 302.11, 'feels_like': 309.11, 'temp_min': 302.11, 'temp_max': 303.2, 'pressure': 1005, 'humidity': 89, 'sea_level': 1005, 'grnd_level': 979}, 'visibility': 10000, 'wind': {'speed': 1.03, 'deg': 0}, 'clouds': {'all': 17}, 'dt': 1787642950, 'sys': {'type': 1, 'id': 9161, 'country': 'IN', 'sunrise': 1787617536, 'sunset': 1787664091}, 'timezone': 19800, 'id': 1273294, 'name': 'Delhi', 'cod': 200}
# ==========Temperture Details delhi==========
# Current Temperture: 28.960000000000036 °C
# ==========Feels like==========
# current Feels Like:31.25755687269132°C
# ===========Temp Min===========
# Current Temp Min: 28.960000000000036°C
# ==========Temp Max===========
# Current Temp Max: 302.11°C
# ======pressure======
# Pressure: 1005
# ==========Humidity==========
# Current Humidity: 89%
# ...
