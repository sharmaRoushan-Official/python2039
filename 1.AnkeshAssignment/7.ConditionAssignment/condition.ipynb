# %%
# Print Days  of week based on number input by user

number = int(input("Enter number between 1 to 7: "))

if number == 1:
    print("sunday")
elif number == 2: 
    print("Monday")
elif number == 3:
    print("Tuesday")
elif number == 4:
    print("wednesday")
elif number == 5:
    print("Thursday")
elif number == 6:
    print("Friday")
elif number == 7:
    print("Saturday")
else:
    print("out of range")
# Out:
# Enter number between 1 to 12 :  2
# Monday

# %%
# Print month  of year based on number input by user

number = int(input("Enter number : "))

if number == 1:
    print("january")
elif number == 2: 
    print("february")
elif number == 3:
    print("March")
elif number == 4:
    print("April")
elif number == 5:
    print("may")
elif number == 6:
    print("june")
elif number == 7:
    print("july")
elif number == 8:
    print("August")
elif number == 9:
    print("September")
elif number == 10:
    print("October")
elif number == 11:
    print("november")
elif number == 12:
    print("december")
else:
    print("out of range")
# Out:
# Enter number :  5
# may

# %%
# 1. Check whether Number is Positive, Negative ,Zero

number = int(input("Enter number : "))

if number==0:
    print("number is 0")
elif number>0:
    print("number is positive")
else:
    print("number is negative")
# Out:
# Enter number :  -1
# number is negative

# %%
# 2. check whether the entered number is odd or Even

number = int(input("Enter number : "))

if number%2==0:
    print("number is even")
else:
    print("number is odd")
# Out:
# Enter number :  0
# number is even

# %%
# 3. check whether the person is Eligible for Vote or Not

age = int(input("Enter your age : "))

if  age>=18:
    print("Eligible for vote")
else:
    print("not eligible for vote")
# Out:
# Enter your age :  12
# not eligible for vote

# %%
# 4. Find the Largest Between Two Number

number1 = int(input("Enter number1 : "))

number2 = int(input("Enter number2 : "))

if number1>number2:
    print(f"{number1} is largest")
elif number2>number1:
    print(f"{number2} is largest")
elif number1==number2:
    print("both are equal")
else:
    print("not a number")
# Out:
# Enter number1 :  23
# Enter number2 :  87
# 87 is largest

# %%
# 5. Check whether the Entered Number is Divisible by 5 or not

number = int(input("Enter number : "))

if number%5==0:
    print(f"{number} divisible by 5")
else:
    print(f"{number} is not divisible by 5")
# Out:
# Enter number :  23
# number is not divisible by 5

# %%
# 6. check whether the entered number is multiple of 3 and 5 both

number = int(input("Enter a Number"))

if number%3==0 and number%5==0:
    print("number is multiple  of 3 and 5 both")
else:
    print("number is not multiple of 3 and 5 both ")
# Out:
# Enter Number 15
# number is divisible  by 3 and 5 both

# %%
# 7. check whether entered character is Vowel or Consonant

character = input("Enter character")

if character=='a' or character=='A'or character=='e' or character=='E' or character=='i' or character=='I' or character=='o' or character=='O' or character=='u' or character=='U':
    print(f"{character} is Vowel")
else:
    print(f"{character} is consonant")
# Out:
# Enter character a
# a is Vowel

# %%
# 8. check Whether Given year is Leap Year or not

year=int(input("Enter a Year "))

if year%400==0:
    print(f"{year} is Leap year")
elif year%4==0:
    print(f"{year} is Leap year")
elif year%100==0:
    print(f"{year} is Not Leap year")
else:
    print("Not a Leap year")
# Out:
# Enter a Year  23
# Not a Leap year

# %% [markdown]
# ##### 9. Check number is with in range of of 1-100

# %%
number=int(input("Enter number to check between 1 to 100:"))

if number>0 and number<=100:
    print(f"{number} is in range of 1-100")
elif number>100:
    print(f"{number} is greater than 100")
elif number==0:
    print("Entered number is zero")
else:
    print(f"{number} is negative")
# Out:
# Enter number to check between 1 to 100: -66
# -66 is negative

# %% [markdown]
# ##### 10. Write a Python program to check if a person is a *child (≤12), **teenager (13–19), or **adult (≥20)*.

# %%
age=int(input("Enter age of person : "))

if age<=12:
    print("Person is child ")
elif age>=13 and age<=19:
    print("Person is Teenager")
elif age>=20:
    print("Person is Adult ")
else:
    print("Invalid Input")
# Out:
# Enter age of person :  13
# Person is Teenager

# %% [markdown]
# ## Intermediate Level
#
# #### 11. Write a Python program to find the *largest among three numbers*.

# %%
num1=int(input("Enter number 1 : "))
num2=int(input("Enter number 2 : "))
num3=int(input("Enter number 3 : "))

if num1>num2 and num1>num3:
    print(f"{num1} is greater than {num2} and {num3}")
if num2>num1 and num2>num3:
    print(f"{num2} is greater than {num1} and {num3}")
if num3>num1 and num3>num2:
    print(f"{num3} is greater than {num1} and {num2}")
# Out:
# Enter number 1 :  32
# Enter number 2 :  12
# Enter number 3 :  55
# 55 is greater than 32 and 12

# %% [markdown]
# ##### 12. Write a Python program to check whether a number is *positive and even, **positive and odd, or **negative*.

# %%
number = int(input("Enter a number : "))
if number>=0:
    if number%2==0:
        print(f"{number} is Positive and Even")
    else:
        print(f"{number} is Positive and Odd")
else:
     if number%2==0:
        print(f"{number} is Negative and Even")
     else:
        print(f"{number} is Negative and Odd")
# Out:
# Enter a number :  0
# 0 is Positive and Even

# %% [markdown]
# ##### 13. Write a Python program to check if a number is *a single-digit, two-digit, or more than two digits*

# %%
number = input("Enter a Number :")
length=len(number)
if length==1:
    print(f"{number} is single digit number")
elif length==2:
    print(f"{number} is Two digit number")
else:
    print(f"{number} is More than two digit number")
# Out:
# Enter a Number : 11
# 11 is Two digit number

# %% [markdown]
# ##### 14. Write a Python program to classify a grade:
#
#     A: 90–100
#     B: 80–89
#     C: 70–79
#     D: 60–69
#     F: Below 60

# %%
percent =float(input("Enter Your Percentage : "))

if percent>=90 and percent<=100:
    print(f"{percent} is A grade ")
elif percent>=80 and percent<90:
    print(f"{percent} is B grade ")
elif percent>=70 and percent<=80:
    print(f"{percent} is C grade ")
elif percent>=60 and percent<70:
    print(f"{percent} is D grade ")
else:
    print(f"{percent} is F grade ")
# Out:
# Enter Your Percentage :  90.1
# 90.1 is A grade

# %% [markdown]
# ##### 15. Write a Python program to check whether a character is a *digit, **uppercase letter, **lowercase letter, or **special character*.

# %%
#import string
#help(string) ---> Used to see  all string

# %%
ascii_lowercase = 'abcdefghijklmnopqrstuvwxyz'
ascii_uppercase = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
digits = '0123456789'
punctuation = '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

char = input("Enter a Character : ")

if char in ascii_lowercase:
    print(f"{char} is Lowercase Letter ")
elif char in ascii_uppercase:
    print(f"{char} is Uppercase Letter ")
elif char in digits:
    print(f"{char} is Digits ")
elif char in punctuation:
    print(f"{char} is Special Character ")
# Out:
# Enter a Character :  A
# A is Uppercase Letter

# %% [markdown]
# ##### 16. Write a Python program to determine whether a given year is a *century year* (divisible by 100) or not.

# %%
year = int(input("Enter a year : "))

if year%100==0:
    print(f"{year} is Century Year ")
else:
    print(f"{year} is not Century Year ")
# Out:
# Enter a year :  800
# 800 is Century Year

# %% [markdown]
# ##### 17. Write a Python program to check whether a triangle is *equilateral, **isosceles, or **scalene*.

# %%
side1 = input("Enter the Value of side 1 of Triangle : ")
side2 = input("Enter the Value of side 2 of Triangle : ")
side3 = input("Enter the Value of side 3 of Triangle : ")

if side1==side2 and side2==side3:
    print("Triangle is Equilateral Triangle ")
elif side1==side2 or side2==side3 or side3==side1:
    print("Triangle is Isosceles Triangle")
else:
    print("Triangle is Scalene Triangle ")
# Out:
# Enter the Value of side 1 of Triangle :  1
# Enter the Value of side 2 of Triangle :  1
# Enter the Value of side 3 of Triangle :  1
# Triangle is Equilateral Triangle

# %% [markdown]
# ##### 18. Write a Python program to check whether the entered password matches the *stored password* or not.

# %%
sPass = input("Enter the Password to store")
print("\n ========== Welcome ==================\n")
cPass = input("Enter Your Password: ")

if(sPass == cPass):
    print("Your Password matched with Device Password ")
else:
    print(" \n !!!  You Have Entered Wrong Password , Please Enter Correct Password ")
# Out:
# Enter the Password to store ankesh
#  ========== Welcome ==================
# Enter Your Password:  Ankesh
#
#  !!!  You Have Entered Wrong Password , Please Enter Correct Password

# %% [markdown]
# ##### 19. Write a Python program to find whether a given temperature (°C) is *cold (<20), **moderate (20–30), or **hot (>30)*.

# %%
temp = int(input("Enter the Temperature : "))
if temp<20:
    print(f"{temp} is Cold temperature ")
elif temp>=20 and temp<=30:
    print(f"{temp} is moderate temperature ")
else:
    print(f"{temp} is Hot Temperature")
# Out:
# Enter the Temperature :  1
# 1 is Cold temperature

# %% [markdown]
# ##### 20.Write a Python program to check if the entered number is *a multiple of 2, 3, both, or none*.

# %%
num = int(input("Enter a Number : "))
if num>0:
    if num%2==0:
        if num%3==0:
            print(f"{num} is multiple of 2 and 3 both  ")
        else:
            print(f"{num} is Multiple of 2 only ")
    elif num%3==0:
        print(f"{num} is Multiple of 3 only")
    else:
        print(f"{num} is neither Multiple of 2 nor 3 ")
else:
    print("Enter Valid Positive Number ")
# Out:
# Enter a Number :  29
# 29 is neither Multiple of 2 nor 3

# %% [markdown]
# ## *Advanced / Real-Life Scenarios (21–30)*

# %% [markdown]
# ##### 21. Write a Python program to calculate *discount* based on purchase amount:
#
# * more than 1000 → 20% discount
# * 500–1000 → 10% discount *
# * less than 500 → No discount

# %%
pAmount = float(input("Enter Purchase Amount"))

if pAmount>1000:
    dis = '20%'
    dAmount =pAmount*0.2
    amount = pAmount-dAmount
    print("====================Receipt====================\n")
    print(f"Discount Percentage is {dis}")
    print(f"Discount Amount is {dAmount}")
    print(f"Payable amount is {amount}")
    
elif pAmount>=500 and pAmount<=1000:
    dis = '10%'
    dAmount =pAmount*0.1
    amount = pAmount-dAmount
    print("====================Receipt====================\n")
    print(f"Discount Percentage is {dis}")
    print(f"Discount Amount is {dAmount}")
    print(f"Payable amount is {amount}")
    
    addAmount = 1001 - pAmount
    print(f"\n            !!!! Warning !!!!         \n Increase Amount by {addAmount} to get 20% Discount ")

elif pAmount<500 and pAmount>0:
    dis = '0%'
    dAmount =pAmount*0
    amount = pAmount-dAmount
    print("====================Receipt====================\n")
    print(f"Discount Percentage is {dis}")
    print(f"Discount Amount is {dAmount}")
    print(f"Payable amount is {amount}")

    addAmount = 500 - pAmount
    print(f"\n             !!!! Warning !!!!      \n Increase Amount by {addAmount} to get 10% Discount ")

else:
    print("You have enter invalid choice ")
# Out:
# Enter Purchase Amount 500
# ====================Receipt====================
#
# Discount Percentage is 10%
# Discount Amount is 50.0
# Payable amount is 450.0
#
#             !!!! Warning !!!!
#  Increase Amount by 501 to get 20% Discount

# %% [markdown]
# ##### 22. Write a Python program to check if a given *day number (1–7)* corresponds to *weekday or weekend*.

# %%
dayNum = int(input("Enter Day Number 1-7"))
weekdays = {2:'monday',3:'tuesday',4:'wednesday',5:'thursday',6:'friday'}
weekend = {7:'saturday',1:'sunday'}

if dayNum in weekdays.keys():
    print(f"Entered day number {dayNum} is weekdays ")
elif dayNum in weekend.keys():
    print(f"Entered day number {dayNum} is Weekend ")
else:
    print("Invalid Input ! Enter Correct day Number ")
# Out:
# Enter Day Number 1-7 2
# Entered day number 2 is weekdays

# %% [markdown]
# ##### 23. Write a Python program to decide the *mode of transport* based on distance:
#
#     * <3 km: Walk
#     * 3–15 km: Bike
#     * > 15 km: Car

# %%
distance = float(input("Enter Distance in KM : "))

if distance<3:
    print("Mode of Transport is Walk ")
elif distance>=3 and distance<=15:
    print("Mode of Transport is Bike ")
elif distance>15:
    print("Mode of Transport is Car ")
else:
    print("Invalid Input ")
# Out:
# Enter Distance in KM :  3.6
# Mode of Transport is Bike

# %% [markdown]
# ##### 24. Write a Python program to check if a *username* starts with a letter and not a number

# %%
username = input("Enter your username : ")
# Out:
# Enter your username :  a

# %% [markdown]
# ##### 25. Write a Python program to calculate the *electricity bill*:
#
#     * ≤100 units → ₹1 per unit
#     * 101–200 units → ₹1.5 per unit
#     * > 200 units → ₹2 per unit

# %%
unit = int(input("Enter the Consumed Electricity Unit : "))

if unit<=100:
    bill = unit*1
    print("\n================= Electricity Bill ==================\n")
    print(f"Bill Amount is ₹{bill} \n")
    
elif unit>100 and unit<=200:
    bill = unit*1.5
    print("\n================= Electricity Bill ==================\n")
    print(f"Bill Amount is ₹{bill} \n")
elif unit>200:
    bill = unit*2
    print("\n================= Electricity Bill ==================\n")
    print(f"Bill Amount is ₹{bill} \n")
else:
    print("Invalid Input")
# Out:
# Enter the Consumed Electricity Unit :  300
# ================= Electricity Bill ==================
#
# Bill Amount is ₹600

# %% [markdown]
# ##### 26. Write a Python program to determine if a student *passed or failed* based on marks in three subjects (passing marks = 40).

# %%
sub1 = float(input("Enter marks of subject 1 out of 100 : "))
sub2 = float(input("Enter marks of subject 2 out of 100  : "))
sub3 =float(input("Enter marks of subject 3 out of 100  : "))

if sub1>=40 and sub2>=40 and sub3>=40:
    print("Student is Passed")
else:
    print("Student is failed")
# Out:
# Enter marks of subject 1 out of 100 :  40.5
# Enter marks of subject 2 out of 100  :  20
# Enter marks of subject 3 out of 100  :  29
# Student is failed

# %% [markdown]
# ##### 27. Write a Python program to check whether a given *year* is a *leap century year* (divisible by both 100 and 400).

# %%
year = int(input("Enter the Year : "))

if year%100

# %% [markdown]
# ##### 28.  Write a Python program to check whether a *bank account balance* is *low (<1000), **medium (1000–5000), or **high (>5000)*.

# %%
balance = float(input("Enter Your Bank Account Balance : "))

if balance<1000:
    print(f"Your Account Balance is Low : {balance}")
elif balance>=1000 and balance<=5000:
    print(f"Your Account Balance is Medium : {balance}")
elif balance>5000:
    print(f"Your Account Balance is High : {balance}")
else:
    print("Invalid Input ")
# Out:
# Enter Your Bank Account Balance :  4000
# Your Account Balance is Medium : 4000

# %% [markdown]
# ##### 29. Write a Python program to classify *BMI (Body Mass Index)*:
#
#     * <18.5 → Underweight
#     * 18.5–24.9 → Normal
#     * 25–29.9 → Overweight
#     * ≥30 → Obese

# %%
bmi = float(input("Enter Your Body Mass Index ( BMI ) : "))

if bmi<18.5:
    print("You are on UnderWeight")
elif bmi>=18.5 and bmi<=24.9:
    print(" You are on Normal Weight ")
elif bmi>=25 and bmi<=29.9:
    print(" You are on Over Weight ")
elif bmi>=30:
    print(" You are on Obese ")
else:
    print("Invalid Input")
# Out:
# Enter Your Body Mass Index ( BMI ) :  23
#  You are on Normal Weight

# %% [markdown]
# ##### 30. Write a Python program to check whether an input string is *number, **only spaces, or **contains characters*.

# %% [markdown]
# # Home Work

# %% [markdown]
#  ### 1. Accepts any city and display their Monuments.
#
# ###### cityName-------------------> Monument
# ######
# ###### "Delhi"--------------------> ['Redfort','QutubMinar','LotusTemple']
# ###### Agra-----------------------> "TajMahal"
# ###### Jaipur---------------------> "HawaMahal/JalMahal"
# ###### Amritsar-------------------> "GoldenTemple,Jalliawalabagh"
# ###### Madurai--------------------> "Meenakshi Temple"
# ###### Mysore---------------------> "Mysore palace"
# ###### Mumbai --------------------> "Gateway of India"
# ###### Sanchi---------------------> "Sanchi Stupa"
# ###### Hydrabad-------------------> "Charminar"
# ###### Gujarat -------------------> "Statue of Unity"

# %%
listCity = ["Delhi","Agra","Jaipur","Amritsar","Madurai","Mysore","Mumbai","Sanchi","Hyderabad","Gujrat"]
print("City List : ",listCity)

cityName1=input("\n Choose City From List ")
cityName = cityName1.capitalize()

if cityName=="Delhi":
    print("Monument is : ",['Redfort','QutubMinar','LotusTemple'])
elif cityName=="Agra":
    print("Monument is : ","Tajmahal")
elif cityName=="Jaipur":
    print("Monument is : ", "HawaMahal/JalMahal")
elif cityName=="Amritsar":
    print("Monument is : ","GoldenTemple,Jalliawalabagh")
elif cityName=="Madurai":
    print("Monument is : ", "Meenakshi Temple")
elif cityName=="Mysore":
    print("Monument is : ","Mysore palace")
elif cityName=="Mumbai":
    print("Monument is : ","Gateway of India")
elif cityName=="Sanchi":
    print("Monument is : ","Sanchi Stupa")
elif cityName=="Hyderabad":
    print("Monument is : ","Charminar")
elif cityName=="Gujrat":
    print("Monument is : ","Statue of Unity")
else:
    print("out of list")
# Out:
# City List :  ['Delhi', 'Agra', 'Jaipur', 'Amritsar', 'Madurai', 'Mysore', 'Mumbai', 'Sanchi', 'Hyderabad', 'Gujrat']
#  Choose City From List  mumbai
# Monument is :  Gateway of India

# %% [markdown]
# ##### 2. A shop wil give you discount of 20%, if the cost of purchased is more than 2000, and     if
# ##### purchased amount will be 1000 more than then it will discount 10%, And if purchased        amount
# ##### is less than 1000- "No discount" as well print how much need more shopping
# ##### amount will to get minimum discount.

# %%
pAmount = float(input("Enter Purchase Amount"))

if pAmount>2000:
    dis = '20%'
    dAmount =pAmount*0.2
    amount = pAmount-dAmount
    print("====================Receipt====================\n")
    print(f"Discount Percentage is {dis}")
    print(f"Discount Amount is {dAmount}")
    print(f"Payable amount is {amount}")
    
elif pAmount>=1000 and pAmount<=2000:
    dis = '10%'
    dAmount =pAmount*0.1
    amount = pAmount-dAmount
    print("====================Receipt====================\n")
    print(f"Discount Percentage is {dis}")
    print(f"Discount Amount is {dAmount}")
    print(f"Payable amount is {amount}")
    
    addAmount = 2001 - pAmount
    print(f"\n            !!!! Warning !!!!         \n Increase Amount by {addAmount} to get 20% Discount ")

elif pAmount<1000 and pAmount>0:
    dis = '0%'
    dAmount =pAmount*0
    amount = pAmount-dAmount
    print("====================Receipt====================\n")
    print(f"Discount Percentage is {dis}")
    print(f"Discount Amount is {dAmount}")
    print(f"Payable amount is {amount}")

    addAmount = 1000 - pAmount
    print(f"\n             !!!! Warning !!!!      \n Increase Amount by {addAmount} to get  minimum 10% Discount ")

else:
    print("You have enter invalid choice ")
# Out:
# Enter Purchase Amount 1001
# ====================Receipt====================
#
# Discount Percentage is 10%
# Discount Amount is 100.10000000000001
# Payable amount is 900.9
#
#             !!!! Warning !!!!
#  Increase Amount by 1000.0 to get 20% Discount

# %% [markdown]
# ##### 3.A compay will decided to give bonus to the employee according to the following criteria:
# ##### Time period of the service -------------------> Bonus
# ##### More then 10 Years ---------------------------> 10%
# ##### >=6 and <=10 ---------------------------------> 8%
# ##### <6 -------------------------------------------> 5%
# ##### Ask the user for their salary and yers of service and then calcualte the bonus amount is,
# ##### and display the total salary after increment of bonus.####

# %%
sal = float(input("Enter Your salary : "))
time = float(input("Enter time period of service ( in Years ) : "))

if time>10 :
    bonusPercent = "10%"
    bonusAmount = sal*10/100
    iSalary = sal+bonusAmount
    print(f"initial Salary is {sal}")
    print(f"Bonus amount by {bonusPercent} is {bonusAmount}")
    print(f"Salary after increment is {iSalary}")

elif time>=6 and time<=10 :
    bonusPercent = "8%"
    bonusAmount = sal*8/100
    iSalary = sal+bonusAmount
    print(f"initial Salary is {sal}")
    print(f"Bonus amount by {bonusPercent} is {bonusAmount}")
    print(f"Salary after increment is {iSalary}")
elif time<6 :
    bonusPercent = "5%"
    bonusAmount = sal*5/100
    iSalary = sal+bonusAmount
    print(f"initial Salary is {sal}")
    print(f"Bonus amount by {bonusPercent} is {bonusAmount}")
    print(f"Salary after increment is {iSalary}")
else:
    print("Invalid Input ")
# Out:
# Enter Your salary :  10000
# Enter time period of service ( in Years ) :  15
# initial Salary is 10000.0
# Bonus amount by 10% is 1000.0
# Salary after increment is 11000.0

# %% [markdown]
# ##### 7. Accept the following from the user and calculate the percentage of the class attendence.
# ##### Total number of working days.
# ##### Total number of absent.
# ##### if percentage is less than 75%, then student will not sit the exam.

# %%
tWorking = int(input("Enter Total Number of Working Days : "))
tAbsent = int(input("Enter Total Number of Absent : "))

present = tWorking - tAbsent
presentPercent = (present*100)/tWorking

if presentPercent >= 75:
    print(f"Students will sit in exam and attendance is {presentPercent}%")
else:
    print(f"Students will not allowed to sit in exam and attendance is {presentPercent}%")
# Out:
# Enter Total Number of Working Days :  100
# Enter Total Number of Absent :  2
# Students will sit in exam and attendance is 98.0%

# %% [markdown]
# ##### 9. Simulate a traffic light, if the light is "Green", print "Go", If yellow, print "Caution",
# ##### if red "Stop!"

# %%
light1 = input("Enter Light Status : ")
light=light1.capitalize()

if light=="Green":
    print("You can go")
elif light=="Yellow":
    print("Caution")
elif light == "Red":
    print("Stop !")
else:
    print("invalid input")
# Out:
# Enter Light Status :  red
# Stop !

# %% [markdown]
# ##### 10. Check user roles, if "admin",print "Access granted", if "Editor",print "Can edit". If viewer
# ##### print "Unknown role"

# %%
role1 = input("Enter User Roles : ")
role = role1.capitalize()
if role == 'Admin':
    print("Access Granted ")
elif role == 'Editor':
    print(" Can edit ")
elif role == 'Viewer':
    print(" Unknown Role ")
else:
    print("Invalid Input ")
# Out:
# Enter User Roles :  admin
# Access Granted

# %%
#11. Apply discount based on purchase amount. If over $100 first show in rupees "₹ 86.99" then 15% discount 
#if over $50, 5% discount, otherwise no discount.

pAmount = float(input("Enter Purchase Amount  in $ "))

if pAmount>=100:
    inr = pAmount  * 86.99
    dis = '15%'
    dAmount = (inr * 15 )/100
    amount = inr + dAmount
    print(f"Discount Amount is ₹{dAmount}")
    print(f"Amount after {dis} is ₹{amount}")

elif pAmount>=50 and pAmount<100:
    inr = pAmount * 86.99
    dis = '5%'
    dAmount = (inr * 5 )/100
    amount = inr + dAmount
    print(f"Discount Amount is ₹{dAmount}")
    print(f"Amount after {dis} is ₹{amount}")
    
elif pAmount<50:
    inr = pAmount * 86.99
    dis = '0%'
    dAmount = (inr * 0 )/100
    amount = inr + dAmount
    print(f"Discount Amount is ₹{dAmount}")
    print(f"Amount after {dis} is ₹{amount}")
    
else:
    print("Invalid Input ")
# Out:
# Enter Purchase Amount  in $  20
# Discount Amount is ₹0.0
# Amount after 0% is ₹1739.8
