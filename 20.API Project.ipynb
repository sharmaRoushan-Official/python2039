# %% [markdown]
# ### 20. API Project

# %%
import requests

# %%
def getWeather():
    api_keys= "f3d23ab84146eaf779dbe1fcb07bc122"
    cityName = "California"
    url = f"https://api.openweathermap.org/data/2.5/weather?q={cityName}&appid={api_keys}"
    # print(url)
    response = requests.get(url)
    print(response)

    if response.status_code == 200:
        data = response.json()
        print(data)

        print(f"===========Temperature Details {cityName}===========")
        temp = data['main']['temp']
        # print(temp)
        # 0K − 273.15 = -273.1°C
        temperature = temp - 273.15
        print("Current Temperature:",temperature,"°C")

        cityName = data['name']
        print("City Name:",cityName)

getWeather()
# Out:
# <Response [200]>
# {'coord': {'lon': -76.5074, 'lat': 38.3004}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 294.97, 'feels_like': 295.51, 'temp_min': 294.16, 'temp_max': 295.91, 'pressure': 1016, 'humidity': 88, 'sea_level': 1016, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 78}, 'dt': 1787630262, 'sys': {'type': 2, 'id': 2027503, 'country': 'US', 'sunrise': 1787567323, 'sunset': 1787615309}, 'timezone': -14400, 'id': 4350049, 'name': 'California', 'cod': 200}
# ===========Temperature Details California===========
# Current Temperature: 21.82000000000005 °C
# City Name: California
